# %% [markdown]
# # CAP 350 - Data Engineering - Capstone Project
#
# Overview:
#
# This Capstone Project requires learners to work with the following technologies to `manage an ETL process` for a `Loan Application dataset` and a `Credit Card dataset`: Python (Pandas, advanced modules, e.g., Matplotlib), SQL, Apache Spark (Spark Core, Spark SQL), and Python Visualization and Analytics libraries. Learners are expected to set up their environments and perform installations on their local machines.

# %% [markdown]
# `Credit Card Dataset Overview`
#
# The Credit Card System database is an independent system developed for managing activities such as registering new customers and approving or canceling requests, etc., using the architecture.
#
# A credit card is issued to users to enact the payment system. It allows the cardholder to access financial services in exchange for the holder's promise to pay for them later. Below are three files that contain the customer’s transaction information and inventories in the credit card information.
#
# - 	`CDW_SAPP_CUSTOMER.JSON`: This file has the existing customer details.
# - 	`CDW_SAPP_CREDITCARD.JSON`: This file contains all credit card transaction information.
# - 	`CDW_SAPP_BRANCH.JSON`: Each branch’s information and details are recorded in this file.

# %% [markdown]
# ### Business Requirements - ETL
# ### 1. Functional Requirements - Load Credit Card Database (SQL)

# %% [markdown]
# 1.1 - Data Extraction and Transformation with Python and PySpark
#
# a)	For “Credit Card System,” create a Python and PySpark SQL program to read/extract the following JSON files according to the specifications found in the mapping document.
#
# - Hint: [You can use  PySQL “select statement query” or simple Pyspark RDD].

# %%
# !.\venv\Scripts\activate

# %%
from pyspark.sql.types import *
from pyspark.sql.functions import *
from pyspark.sql import SparkSession
ss = SparkSession.builder.appName("Credit_Card_System").getOrCreate()
ss
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://Lazzypotatoe.mshome.net:4041">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.4.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Credit_Card_System</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
# import and read json files into pyspark df
# json files don't have the same concept of column headers as csv files and is a self-describing data format, hence no need to specify header and infer schema
branch = ss.read.json("cdw_sapp_branch.json")
credit = ss.read.json("cdw_sapp_credit.json")
customer = ss.read.json("cdw_sapp_customer.json")

# %%
# inspect data in branch df
branch.printSchema()
print(branch.schema)
branch.show(5, truncate=False)
# Out:
# root
#  |-- BRANCH_CITY: string (nullable = true)
#  |-- BRANCH_CODE: long (nullable = true)
#  |-- BRANCH_NAME: string (nullable = true)
#  |-- BRANCH_PHONE: string (nullable = true)
#  |-- BRANCH_STATE: string (nullable = true)
#  |-- BRANCH_STREET: string (nullable = true)
#  |-- BRANCH_ZIP: long (nullable = true)
#  |-- LAST_UPDATED: string (nullable = true)
#
# StructType([StructField('BRANCH_CITY', StringType(), True), StructField('BRANCH_CODE', LongType(), True), StructField('BRANCH_NAME', StringType(), True), StructField('BRANCH_PHONE', StringType(), True), StructField('BRANCH_STATE', StringType(), True), StructField('BRANCH_STREET', StringType(), True), StructField('BRANCH_ZIP', LongType(), True), StructField('LAST_UPDATED', StringType(), True)])
# +-----------------+-----------+------------+------------+------------+-----------------+----------+-----------------------------+
# |BRANCH_CITY      |BRANCH_CODE|BRANCH_NAME |BRANCH_PHONE|BRANCH_STATE|BRANCH_STREET    |BRANCH_ZIP|LAST_UPDATED                 |
# +-----------------+-----------+------------+------------+------------+-----------------+----------+-----------------------------+
# |Lakeville        |1          |Example Bank|1234565276  |MN          |Bridle Court     |55044     |2018-04-18T16:51:47.000-04:00|
# |Huntley          |2          |Example Bank|1234618993  |IL          |Washington Street|60142     |2018-04-18T16:51:47.000-04:00|
# |SouthRichmondHill|3          |Example Bank|1234985926  |NY          |Warren Street    |11419     |2018-04-18T16:51:47.000-04:00|
# |Middleburg       |4          |Example Bank|1234663064  |FL          |Cleveland Street |32068     |2018-04-18T16:51:47.000-04:00|
# |KingOfPrussia    |5          |Example Bank|1234849701  |PA          |14th Street      |19406     |2018-04-18T16:51:47.000-04:00|
# +-----------------+-----------+------------+------------+------------+-----------------+----------+-----------------------------+
# only showing top 5 rows

# %%
branch.filter(isnull(branch['BRANCH_ZIP'])).show(truncate=False)
# Out:
# +-----------+-----------+-----------+------------+------------+-------------+----------+------------+
# |BRANCH_CITY|BRANCH_CODE|BRANCH_NAME|BRANCH_PHONE|BRANCH_STATE|BRANCH_STREET|BRANCH_ZIP|LAST_UPDATED|
# +-----------+-----------+-----------+------------+------------+-------------+----------+------------+
# +-----------+-----------+-----------+------------+------------+-------------+----------+------------+

# %%
test = branch.withColumns({'BRANCH_CODE': branch['BRANCH_CODE'].cast(IntegerType()),
                           'BRANCH_NAME': branch['BRANCH_NAME'].cast(VarcharType(length=150))})  # same as StringType(), leave as it is
test.printSchema()
[test.schema]
# Out:
# root
#  |-- BRANCH_CITY: string (nullable = true)
#  |-- BRANCH_CODE: integer (nullable = true)
#  |-- BRANCH_NAME: string (nullable = true)
#  |-- BRANCH_PHONE: string (nullable = true)
#  |-- BRANCH_STATE: string (nullable = true)
#  |-- BRANCH_STREET: string (nullable = true)
#  |-- BRANCH_ZIP: long (nullable = true)
#  |-- LAST_UPDATED: string (nullable = true)
# [StructType([StructField('BRANCH_CITY', StringType(), True), StructField('BRANCH_CODE', IntegerType(), True), StructField('BRANCH_NAME', StringType(), True), StructField('BRANCH_PHONE', StringType(), True), StructField('BRANCH_STATE', StringType(), True), StructField('BRANCH_STREET', StringType(), True), StructField('BRANCH_ZIP', LongType(), True), StructField('LAST_UPDATED', StringType(), True)])]

# %%
# convert phone number formatting to (xxx)xxx-xxxx
branch = branch.withColumn('BRANCH_PHONE', concat(lit("("), substring(col('BRANCH_PHONE'), 1, 3), lit(")"),
                                                  substring(col('BRANCH_PHONE'), 4, 3), lit("-"), substring(col('BRANCH_PHONE'), 7, 4)))

# replace null values in branch_zip column with 99999, df.fillna() updates the df in-place
branch.fillna({'BRANCH_ZIP': 99999})

# transform data type and rearrange columns
branch = branch.select(branch["BRANCH_CODE"].cast(IntegerType()),
                       "BRANCH_NAME",
                       "BRANCH_STREET",
                       "BRANCH_CITY",
                       "BRANCH_STATE",
                       branch["BRANCH_ZIP"].cast(IntegerType()),
                       "BRANCH_PHONE",
                       branch["LAST_UPDATED"].cast(TimestampType()))

# inspect new df
branch.printSchema()
branch.show(15)
branch.filter(isnull(branch['BRANCH_ZIP'])).show(5)
# Out:
# root
#  |-- BRANCH_CODE: integer (nullable = true)
#  |-- BRANCH_NAME: string (nullable = true)
#  |-- BRANCH_STREET: string (nullable = true)
#  |-- BRANCH_CITY: string (nullable = true)
#  |-- BRANCH_STATE: string (nullable = true)
#  |-- BRANCH_ZIP: integer (nullable = true)
#  |-- BRANCH_PHONE: string (nullable = true)
#  |-- LAST_UPDATED: timestamp (nullable = true)
# +-----------+------------+-----------------+-----------------+------------+----------+-------------+-------------------+
# |BRANCH_CODE| BRANCH_NAME|    BRANCH_STREET|      BRANCH_CITY|BRANCH_STATE|BRANCH_ZIP| BRANCH_PHONE|       LAST_UPDATED|
# +-----------+------------+-----------------+-----------------+------------+----------+-------------+-------------------+
# |          1|Example Bank|     Bridle Court|        Lakeville|          MN|     55044|(123)456-5276|2018-04-18 13:51:47|
# |          2|Example Bank|Washington Street|          Huntley|          IL|     60142|(123)461-8993|2018-04-18 13:51:47|
# |          3|Example Bank|    Warren Street|SouthRichmondHill|          NY|     11419|(123)498-5926|2018-04-18 13:51:47|
# |          4|Example Bank| Cleveland Street|       Middleburg|          FL|     32068|(123)466-3064|2018-04-18 13:51:47|
# |          5|Example Bank|      14th Street|    KingOfPrussia|          PA|     19406|(123)484-9701|2018-04-18 13:51:47|
# |          7|Example Bank| Jefferson Street|         Paterson|          NJ|      7501|(123)414-4890|2018-04-18 13:51:47|
# |          8|Example Bank|         B Street|        Pittsford|          NY|     14534|(123)467-8272|2018-04-18 13:51:47|
# |          9|Example Bank|  Jefferson Court|     Wethersfield|          CT|      6109|(123)467-5219|2018-04-18 13:51:47|
# |         10|Example Bank|   Cambridge Road|     NorthOlmsted|          OH|     44070|(123)414-5047|2018-04-18 13:51:47|
# |         11|Example Bank|  3rd Street West|     Hillsborough|          NJ|      8844|(123)436-6354|2018-04-18 13:51:47|
# |         12|Example Bank|        Mill Road|   MadisonHeights|          MI|     48071|(123)486-7175|2018-04-18 13:51:47|
# |         14|Example Bank|Washington Street|           Oviedo|          FL|     32765|(123)493-8460|2018-04-18 13:51:47|
# |         15|Example Bank|  Chestnut Street|    Mechanicsburg|          PA|     17050|(123)446-2043|2018-04-18 13:51:47|
# |         16|Example Bank|     Monroe Drive|        Plainview|          NY|     11803|(123)485-7525|2018-04-18 13:51:47|
# |         17|Example Bank|  Railroad Street|          Paducah|          KY|     42001|(123)454-6360|2018-04-18 13:51:47|
# +-----------+------------+-----------------+-----------------+------------+----------+-------------+-------------------+
# only showing top 15 rows
#
# +-----------+-----------+-------------+-----------+------------+----------+------------+------------+
# |BRANCH_CODE|BRANCH_NAME|BRANCH_STREET|BRANCH_CITY|BRANCH_STATE|BRANCH_ZIP|BRANCH_PHONE|LAST_UPDATED|
# +-----------+-----------+-------------+-----------+------------+----------+------------+------------+
# +-----------+-----------+-------------+-----------+------------+----------+------------+------------+

# %%
# inspect data in credit df
credit.printSchema()
print(credit.schema)
credit.show(5, truncate=False)
# Out:
# root
#  |-- BRANCH_CODE: long (nullable = true)
#  |-- CREDIT_CARD_NO: string (nullable = true)
#  |-- CUST_SSN: long (nullable = true)
#  |-- DAY: long (nullable = true)
#  |-- MONTH: long (nullable = true)
#  |-- TRANSACTION_ID: long (nullable = true)
#  |-- TRANSACTION_TYPE: string (nullable = true)
#  |-- TRANSACTION_VALUE: double (nullable = true)
#  |-- YEAR: long (nullable = true)
#
# StructType([StructField('BRANCH_CODE', LongType(), True), StructField('CREDIT_CARD_NO', StringType(), True), StructField('CUST_SSN', LongType(), True), StructField('DAY', LongType(), True), StructField('MONTH', LongType(), True), StructField('TRANSACTION_ID', LongType(), True), StructField('TRANSACTION_TYPE', StringType(), True), StructField('TRANSACTION_VALUE', DoubleType(), True), StructField('YEAR', LongType(), True)])
# +-----------+----------------+---------+---+-----+--------------+----------------+-----------------+----+
# |BRANCH_CODE|CREDIT_CARD_NO  |CUST_SSN |DAY|MONTH|TRANSACTION_ID|TRANSACTION_TYPE|TRANSACTION_VALUE|YEAR|
# +-----------+----------------+---------+---+-----+--------------+----------------+-----------------+----+
# |114        |4210653349028689|123459988|14 |2    |1             |Education       |78.9             |2018|
# |35         |4210653349028689|123459988|20 |3    |2             |Entertainment   |14.24            |2018|
# |160        |4210653349028689|123459988|8  |7    |3             |Grocery         |56.7             |2018|
# |114        |4210653349028689|123459988|19 |4    |4             |Entertainment   |59.73            |2018|
# |93         |4210653349028689|123459988|10 |10   |5             |Gas             |3.59             |2018|
# +-----------+----------------+---------+---+-----+--------------+----------------+-----------------+----+
# only showing top 5 rows

# %%
# add new column concatenating year-month-day
credit = credit.withColumn('TIMEID', concat(col('YEAR'), lit(
    '-'), col('MONTH'), lit('-'), col('DAY')).cast(DateType()))
credit.show(5)
# Out:
# +-----------+----------------+---------+---+-----+--------------+----------------+-----------------+----+----------+
# |BRANCH_CODE|  CREDIT_CARD_NO| CUST_SSN|DAY|MONTH|TRANSACTION_ID|TRANSACTION_TYPE|TRANSACTION_VALUE|YEAR|    TIMEID|
# +-----------+----------------+---------+---+-----+--------------+----------------+-----------------+----+----------+
# |        114|4210653349028689|123459988| 14|    2|             1|       Education|             78.9|2018|2018-02-14|
# |         35|4210653349028689|123459988| 20|    3|             2|   Entertainment|            14.24|2018|2018-03-20|
# |        160|4210653349028689|123459988|  8|    7|             3|         Grocery|             56.7|2018|2018-07-08|
# |        114|4210653349028689|123459988| 19|    4|             4|   Entertainment|            59.73|2018|2018-04-19|
# |         93|4210653349028689|123459988| 10|   10|             5|             Gas|             3.59|2018|2018-10-10|
# +-----------+----------------+---------+---+-----+--------------+----------------+-----------------+----+----------+
# only showing top 5 rows

# %%
# transform data type and rearrange columns
credit = credit.select(credit['CREDIT_CARD_NO'].alias("CUST_CC_NO"),
                       credit['TIMEID'],
                       credit['CUST_SSN'].cast(IntegerType()),
                       credit['BRANCH_CODE'].cast(IntegerType()),
                       credit['TRANSACTION_TYPE'],
                       credit['TRANSACTION_VALUE'],
                       credit['TRANSACTION_ID'].cast(IntegerType()))

# inspect new df
credit.printSchema()
credit.show(15, truncate=False)
# Out:
# root
#  |-- CUST_CC_NO: string (nullable = true)
#  |-- TIMEID: date (nullable = true)
#  |-- CUST_SSN: integer (nullable = true)
#  |-- BRANCH_CODE: integer (nullable = true)
#  |-- TRANSACTION_TYPE: string (nullable = true)
#  |-- TRANSACTION_VALUE: double (nullable = true)
#  |-- TRANSACTION_ID: integer (nullable = true)
#
# +----------------+----------+---------+-----------+----------------+-----------------+--------------+
# |CUST_CC_NO      |TIMEID    |CUST_SSN |BRANCH_CODE|TRANSACTION_TYPE|TRANSACTION_VALUE|TRANSACTION_ID|
# +----------------+----------+---------+-----------+----------------+-----------------+--------------+
# |4210653349028689|2018-02-14|123459988|114        |Education       |78.9             |1             |
# |4210653349028689|2018-03-20|123459988|35         |Entertainment   |14.24            |2             |
# |4210653349028689|2018-07-08|123459988|160        |Grocery         |56.7             |3             |
# |4210653349028689|2018-04-19|123459988|114        |Entertainment   |59.73            |4             |
# |4210653349028689|2018-10-10|123459988|93         |Gas             |3.59             |5             |
# |4210653349028689|2018-05-28|123459988|164        |Education       |6.89             |6             |
# |4210653349028689|2018-05-19|123459988|119        |Entertainment   |43.39            |7             |
# |4210653349028689|2018-08-08|123459988|23         |Gas             |95.39            |8             |
# |4210653349028689|2018-03-18|123459988|166        |Entertainment   |93.26            |9             |
# |4210653349028689|2018-09-03|123459988|83         |Bills           |100.38           |10            |
# |4210653349028689|2018-08-21|123459988|52         |Gas             |98.75            |11            |
# |4210653349028689|2018-12-24|123459988|17         |Gas             |42.71            |12            |
# |4210653349028689|2018-04-03|123459988|80         |Grocery         |40.24            |13            |
# |4210653349028689|2018-04-15|123459988|50         |Bills           |17.81            |14            |
# |4210653349028689|2018-05-17|123459988|123        |Bills           |29.0             |15            |
# +----------------+----------+---------+-----------+----------------+-----------------+--------------+
# only showing top 15 rows

# %%
# inspect data in customer df
customer.printSchema()
print(customer.schema)
customer.show(5, truncate=False)
# Out:
# root
#  |-- APT_NO: string (nullable = true)
#  |-- CREDIT_CARD_NO: string (nullable = true)
#  |-- CUST_CITY: string (nullable = true)
#  |-- CUST_COUNTRY: string (nullable = true)
#  |-- CUST_EMAIL: string (nullable = true)
#  |-- CUST_PHONE: long (nullable = true)
#  |-- CUST_STATE: string (nullable = true)
#  |-- CUST_ZIP: string (nullable = true)
#  |-- FIRST_NAME: string (nullable = true)
#  |-- LAST_NAME: string (nullable = true)
#  |-- LAST_UPDATED: string (nullable = true)
#  |-- MIDDLE_NAME: string (nullable = true)
#  |-- SSN: long (nullable = true)
#  |-- STREET_NAME: string (nullable = true)
#
# StructType([StructField('APT_NO', StringType(), True), StructField('CREDIT_CARD_NO', StringType(), True), StructField('CUST_CITY', StringType(), True), StructField('CUST_COUNTRY', StringType(), True), StructField('CUST_EMAIL', StringType(), True), StructField('CUST_PHONE', LongType(), True), StructField('CUST_STATE', StringType(), True), StructField('CUST_ZIP', StringType(), True), StructField('FIRST_NAME', StringType(), True), StructField('LAST_NAME', StringType(), True), StructField('LAST_UPDATED', StringType(), True), StructField('MIDDLE_NAME', StringType(), True), StructField('SSN', LongType(), True), StructField('STREET_NAME', StringType(), True)])
# +------+----------------+------------+-------------+-------------------+----------+----------+--------+----------+---------+-----------------------------+-----------+---------+-----------------+
# |APT_NO|CREDIT_CARD_NO  |CUST_CITY   |CUST_COUNTRY |CUST_EMAIL         |CUST_PHONE|CUST_STATE|CUST_ZIP|FIRST_NAME|LAST_NAME|LAST_UPDATED                 |MIDDLE_NAME|SSN      |STREET_NAME      |
# +------+----------------+------------+-------------+-------------------+----------+----------+--------+----------+---------+-----------------------------+-----------+---------+-----------------+
# |656   |4210653310061055|Natchez     |United States|AHooper@example.com|1237818   |MS        |39120   |Alec      |Hooper   |2018-04-21T12:49:02.000-04:00|Wm         |123456100|Main Street North|
# |829   |4210653310102868|Wethersfield|United States|EHolman@example.com|1238933   |CT        |06109   |Etta      |Holman   |2018-04-21T12:49:02.000-04:00|Brendan    |123453023|Redwood Drive    |
# |683   |4210653310116272|Huntley     |United States|WDunham@example.com|1243018   |IL        |60142   |Wilber    |Dunham   |2018-04-21T12:49:02.000-04:00|Ezequiel   |123454487|12th Street East |
# |253   |4210653310195948|NewBerlin   |United States|EHardy@example.com |1243215   |WI        |53151   |Eugenio   |Hardy    |2018-04-21T12:49:02.000-04:00|Trina      |123459758|Country Club Road|
# |301   |4210653310356919|ElPaso      |United States|WAyers@example.com |1242074   |TX        |79930   |Wilfred   |Ayers    |2018-04-21T12:49:02.000-04:00|May        |123454431|Madison Street   |
# +------+----------------+------------+-------------+-------------------+----------+----------+--------+----------+---------+-----------------------------+-----------+---------+-----------------+
# only showing top 5 rows

# %%
test = customer.withColumn('CUST_PHONE', concat(
    lit('('), col('CUST_PHONE')[0:3], lit(')')))
test.show(5)
# Out:
# +------+----------------+------------+-------------+-------------------+----------+----------+--------+----------+---------+--------------------+-----------+---------+-----------------+
# |APT_NO|  CREDIT_CARD_NO|   CUST_CITY| CUST_COUNTRY|         CUST_EMAIL|CUST_PHONE|CUST_STATE|CUST_ZIP|FIRST_NAME|LAST_NAME|        LAST_UPDATED|MIDDLE_NAME|      SSN|      STREET_NAME|
# +------+----------------+------------+-------------+-------------------+----------+----------+--------+----------+---------+--------------------+-----------+---------+-----------------+
# |   656|4210653310061055|     Natchez|United States|AHooper@example.com|     (123)|        MS|   39120|      Alec|   Hooper|2018-04-21T12:49:...|         Wm|123456100|Main Street North|
# |   829|4210653310102868|Wethersfield|United States|EHolman@example.com|     (123)|        CT|   06109|      Etta|   Holman|2018-04-21T12:49:...|    Brendan|123453023|    Redwood Drive|
# |   683|4210653310116272|     Huntley|United States|WDunham@example.com|     (124)|        IL|   60142|    Wilber|   Dunham|2018-04-21T12:49:...|   Ezequiel|123454487| 12th Street East|
# |   253|4210653310195948|   NewBerlin|United States| EHardy@example.com|     (124)|        WI|   53151|   Eugenio|    Hardy|2018-04-21T12:49:...|      Trina|123459758|Country Club Road|
# |   301|4210653310356919|      ElPaso|United States| WAyers@example.com|     (124)|        TX|   79930|   Wilfred|    Ayers|2018-04-21T12:49:...|        May|123454431|   Madison Street|
# +------+----------------+------------+-------------+-------------------+----------+----------+--------+----------+---------+--------------------+-----------+---------+-----------------+
# only showing top 5 rows

# %%
# change the case of strings and convert phone number formatting to (xxx)xxx-xxxx
customer = customer.withColumns({'FIRST_NAME': initcap(col('FIRST_NAME')),
                                 'MIDDLE_NAME': lower(col('MIDDLE_NAME')),
                                 'LAST_NAME': initcap(col('LAST_NAME')),
                                 'FULL_STREET_ADDRESS': concat(col('STREET_NAME'), lit(', '), col('APT_NO')),
                                 'CUST_PHONE': concat(lit('(XXX)'), col('CUST_PHONE')[0:3], lit('-'), col('CUST_PHONE')[4:7])})  # phone num is missing area code

customer.show(5, truncate=False)
# Out:
# +------+----------------+------------+-------------+-------------------+-------------+----------+--------+----------+---------+-----------------------------+-----------+---------+-----------------+----------------------+
# |APT_NO|CREDIT_CARD_NO  |CUST_CITY   |CUST_COUNTRY |CUST_EMAIL         |CUST_PHONE   |CUST_STATE|CUST_ZIP|FIRST_NAME|LAST_NAME|LAST_UPDATED                 |MIDDLE_NAME|SSN      |STREET_NAME      |FULL_STREET_ADDRESS   |
# +------+----------------+------------+-------------+-------------------+-------------+----------+--------+----------+---------+-----------------------------+-----------+---------+-----------------+----------------------+
# |656   |4210653310061055|Natchez     |United States|AHooper@example.com|(XXX)123-7818|MS        |39120   |Alec      |Hooper   |2018-04-21T12:49:02.000-04:00|wm         |123456100|Main Street North|Main Street North, 656|
# |829   |4210653310102868|Wethersfield|United States|EHolman@example.com|(XXX)123-8933|CT        |06109   |Etta      |Holman   |2018-04-21T12:49:02.000-04:00|brendan    |123453023|Redwood Drive    |Redwood Drive, 829    |
# |683   |4210653310116272|Huntley     |United States|WDunham@example.com|(XXX)124-3018|IL        |60142   |Wilber    |Dunham   |2018-04-21T12:49:02.000-04:00|ezequiel   |123454487|12th Street East |12th Street East, 683 |
# |253   |4210653310195948|NewBerlin   |United States|EHardy@example.com |(XXX)124-3215|WI        |53151   |Eugenio   |Hardy    |2018-04-21T12:49:02.000-04:00|trina      |123459758|Country Club Road|Country Club Road, 253|
# |301   |4210653310356919|ElPaso      |United States|WAyers@example.com |(XXX)124-2074|TX        |79930   |Wilfred   |Ayers    |2018-04-21T12:49:02.000-04:00|may        |123454431|Madison Street   |Madison Street, 301   |
# +------+----------------+------------+-------------+-------------------+-------------+----------+--------+----------+---------+-----------------------------+-----------+---------+-----------------+----------------------+
# only showing top 5 rows

# %%
# transform data type and rearrange columns
customer = customer.select(col('SSN').cast(IntegerType()),
                           'FIRST_NAME',
                           'MIDDLE_NAME',
                           'LAST_NAME',
                           'CREDIT_CARD_NO',
                           'FULL_STREET_ADDRESS',
                           'CUST_CITY',
                           'CUST_STATE',
                           'CUST_COUNTRY',
                           col('CUST_ZIP').cast(IntegerType()),
                           col('CUST_PHONE').cast(VarcharType(length=20)),
                           'CUST_EMAIL',
                           col('LAST_UPDATED').cast(TimestampType()))

# inspect new df
customer.printSchema()
customer.show(15, truncate=False)
# Out:
# root
#  |-- SSN: integer (nullable = true)
#  |-- FIRST_NAME: string (nullable = true)
#  |-- MIDDLE_NAME: string (nullable = true)
#  |-- LAST_NAME: string (nullable = true)
#  |-- CREDIT_CARD_NO: string (nullable = true)
#  |-- FULL_STREET_ADDRESS: string (nullable = true)
#  |-- CUST_CITY: string (nullable = true)
#  |-- CUST_STATE: string (nullable = true)
#  |-- CUST_COUNTRY: string (nullable = true)
#  |-- CUST_ZIP: integer (nullable = true)
#  |-- CUST_PHONE: string (nullable = true)
#  |-- CUST_EMAIL: string (nullable = true)
#  |-- LAST_UPDATED: timestamp (nullable = true)
# +---------+----------+-----------+---------+----------------+----------------------+------------+----------+-------------+--------+-------------+---------------------+-------------------+
# |SSN      |FIRST_NAME|MIDDLE_NAME|LAST_NAME|CREDIT_CARD_NO  |FULL_STREET_ADDRESS   |CUST_CITY   |CUST_STATE|CUST_COUNTRY |CUST_ZIP|CUST_PHONE   |CUST_EMAIL           |LAST_UPDATED       |
# +---------+----------+-----------+---------+----------------+----------------------+------------+----------+-------------+--------+-------------+---------------------+-------------------+
# |123456100|Alec      |wm         |Hooper   |4210653310061055|Main Street North, 656|Natchez     |MS        |United States|39120   |(XXX)123-7818|AHooper@example.com  |2018-04-21 09:49:02|
# |123453023|Etta      |brendan    |Holman   |4210653310102868|Redwood Drive, 829    |Wethersfield|CT        |United States|6109    |(XXX)123-8933|EHolman@example.com  |2018-04-21 09:49:02|
# |123454487|Wilber    |ezequiel   |Dunham   |4210653310116272|12th Street East, 683 |Huntley     |IL        |United States|60142   |(XXX)124-3018|WDunham@example.com  |2018-04-21 09:49:02|
# |123459758|Eugenio   |trina      |Hardy    |4210653310195948|Country Club Road, 253|NewBerlin   |WI        |United States|53151   |(XXX)124-3215|EHardy@example.com   |2018-04-21 09:49:02|
# |123454431|Wilfred   |may        |Ayers    |4210653310356919|Madison Street, 301   |ElPaso      |TX        |United States|79930   |(XXX)124-2074|WAyers@example.com   |2018-04-21 09:49:02|
# |123454202|Beau      |ambrose    |Woodard  |4210653310395982|Colonial Drive, 3     |NorthOlmsted|OH        |United States|44070   |(XXX)124-2570|BWoodard@example.com |2018-04-21 09:49:02|
# |123451799|Sheila    |larry      |Kemp     |4210653310400536|Belmont Avenue, 84    |Vienna      |VA        |United States|22180   |(XXX)123-9685|SKemp@example.com    |2018-04-21 09:49:02|
# |123453875|Wendy     |ora        |Hurley   |4210653310459911|Oxford Court, 728     |Duarte      |CA        |United States|91010   |(XXX)123-8213|WHurley@example.com  |2018-04-21 09:49:02|
# |123457511|Alec      |tracie     |Gilmore  |4210653310773972|Forest Street, 81     |Owosso      |MI        |United States|48867   |(XXX)124-0689|AGilmore@example.com |2018-04-21 09:49:02|
# |123457464|Barbra    |mitchel    |Lau      |4210653310794854|Court Street, 561     |Zion        |IL        |United States|60099   |(XXX)123-5222|BLau@example.com     |2018-04-21 09:49:02|
# |123457639|Edmundo   |denny      |Thomson  |4210653310817373|Cypress Court, 622    |Youngstown  |OH        |United States|44512   |(XXX)124-1363|EThomson@example.com |2018-04-21 09:49:02|
# |123453242|Elsa      |isabelle   |Truong   |4210653310844617|8th Street West, 924  |Summerville |SC        |United States|29483   |(XXX)123-6228|ETruong@example.com  |2018-04-21 09:49:02|
# |123454339|Homer     |henry      |Mckinney |4210653311015303|East Avenue, 611      |ElPaso      |TX        |United States|79930   |(XXX)123-8165|HMckinney@example.com|2018-04-21 09:49:02|
# |123454537|Rita      |rickey     |Kidd     |4210653311215039|Route 44, 680         |Fenton      |MI        |United States|48430   |(XXX)123-4730|RKidd@example.com    |2018-04-21 09:49:02|
# |123452373|Amalia    |heriberto  |Ballard  |4210653311229354|Warren Street, 71     |Grandville  |MI        |United States|49418   |(XXX)124-2113|ABallard@example.com |2018-04-21 09:49:02|
# +---------+----------+-----------+---------+----------------+----------------------+------------+----------+-------------+--------+-------------+---------------------+-------------------+
# only showing top 15 rows

# %% [markdown]
# 1.2 - Data loading into Database
#
# Once PySpark reads data from JSON files, and then utilizes Python, PySpark, and Python modules to load data into RDBMS(SQL), perform the following:
#
# a)	Create a Database in SQL(MySQL), named “creditcard_capstone.”

# %%
# import mysql.connector
# from mysql.connector import Error, errorcode
# import os

# # def connect_to_mysql():
# try:
#     # establish a connection to mysql db
#     cnx = mysql.connector.connect(host = 'localhost',
#                                   user = os.environ.get('MYSQL_DB_USER'),
#                                   password = os.environ.get('MYSQL_DB_PW'))

#     if cnx.is_connected():
#         print("Connection established.")
#     else:
#         print("Connection failed.")

# except Error as e:
#         print(e)
# Out:
# Connection established.

# %%
# # def create_db(cnx):
# try:
#     # create cursor obj to execute sql query
#     cursor = cnx.cursor()
#     # query to create new db
#     cursor.execute("CREATE DATABASE IF NOT EXISTS creditcard_capstone")
#     print("Database 'creditcard_capstone' is created.")

# except Error as e:
#     print(f"Failed to create database: {e}")
# Out:
# Database 'creditcard_capstone' is created.

# %%
# # connect to mysql db + create new db
# try:
#     # establish a connection to mysql db
#     cnx = mysql.connector.connect(host = 'localhost',
#                                   user = os.environ.get('MYSQL_DB_USER'),
#                                   password = os.environ.get('MYSQL_DB_PW'))

#     if cnx.is_connected():
#         print("Connection established.")
#         # create cursor obj to execute sql query
#         cursor = cnx.cursor()
#         # query to create new db
#         cursor.execute("CREATE DATABASE IF NOT EXISTS creditcard_capstone")
#         print("Database 'creditcard_capstone' is created.")

# except Error as e:
#         print(e)

# %%
#  MySQL  localhost:33060+ ssl  SQL > SHOW DATABASES;
# +---------------------+
# | Database            |
# +---------------------+
# | classicmodels       |
# | companyabc_db       |
# | creditcard_capstone |   <---
# | information_schema  |
# | mysql               |
# | performance_schema  |
# | sakila              |
# | sys                 |
# | userdb              |
# | world               |
# +---------------------+
# 10 rows in set (0.0025 sec)

# %%
import mysql.connector
from mysql.connector import Error
import os


def connect_to_mysql():
    # establish connection to mysql db
    cnx = mysql.connector.connect(host='localhost',
                                  user=os.environ.get('MYSQL_DB_USER'),
                                  password=os.environ.get('MYSQL_DB_PW'))
    return cnx
    # the return statement enables use of the connection outside the function

# %%
def create_db(db_name):
    try:
        # the with statement ensures that the connection is automatically closed when the with block is exited, hence no need to explicitly call cnx.close()
        with connect_to_mysql() as cnx:
            # create cursor obj to execute sql query
            cursor = cnx.cursor()
            # query to create new db
            cursor.execute("CREATE DATABASE IF NOT EXISTS db_name")
            print(f"Database {db_name} is created.")

    except Error as e:
        print(e)


create_db("creditcard_capstone")
# Out:
# Database creditcard_capstone is created.

# %% [markdown]
# b)	Create a Python and Pyspark Program to load/write the “Credit Card System Data” into RDBMS(creditcard_capstone).
#
# Tables should be created by the following names in RDBMS:
# - CDW_SAPP_BRANCH
# - CDW_SAPP_CREDIT_CARD
# - CDW_SAPP_CUSTOMER

# %%
def load_data():
    with connect_to_mysql() as cnx:
        cursor = cnx.cursor()
        # check if db is empty by counting the num of tables inside
        cursor.execute(
            "select count(distinct table_name) from information_schema.tables where table_schema = 'creditcard_capstone'")
        count = cursor.fetchone()  # fetchone() gets the 1st row = (4,)
        print(count[0])


load_data()
# Out:
# 4

# %%
# load data from branch df into new table in db
# drop the entire database first if re-runnning/repeating below actions in append mode, otherwise the same set of data will get appended again to the same table, causing duplicates in data
branch.write.format("jdbc")\
    .mode("append")\
    .options(user=os.environ.get("MYSQL_DB_USER"),
             password=os.environ.get("MYSQL_DB_PW"),
             url="jdbc:mysql://localhost:3306/creditcard_capstone",
             dbtable="creditcard_capstone.CDW_SAPP_BRANCH")\
    .save()

# %%
# load data from credit df into new table in db
credit.write.format("jdbc")\
    .mode("append")\
    .options(user=os.environ.get("MYSQL_DB_USER"),
             password=os.environ.get("MYSQL_DB_PW"),
             url="jdbc:mysql://localhost:3306/creditcard_capstone",
             dbtable="creditcard_capstone.CDW_SAPP_CREDIT_CARD")\
    .save()

# %%
# load data from customer df into new table in db
customer.write.format("jdbc")\
    .mode("append")\
    .options(user=os.environ.get("MYSQL_DB_USER"),
             password=os.environ.get("MYSQL_DB_PW"),
             url="jdbc:mysql://localhost:3306/creditcard_capstone",
             dbtable="creditcard_capstone.CDW_SAPP_CUSTOMER")\
    .save()

# %%
#  MySQL  localhost:33060+ ssl  creditcard_capstone  SQL > SHOW TABLES;
# +-------------------------------+
# | Tables_in_creditcard_capstone |
# +-------------------------------+
# | cdw_sapp_branch               |
# | cdw_sapp_credit_card          |
# | cdw_sapp_customer             |
# +-------------------------------+
# 3 rows in set (0.0024 sec)

# %% [markdown]
# ### 2. Functional Requirements - Application Front-End
# Once data is loaded into the database, we need a front-end (console) to see/display data. For that, create a console-based Python program to satisfy System Requirements 2 (2.1 and 2.2).
#
# 2.1 - Transaction Details Module
# - module is a .py file containing Python definitions and statements and can be imported into another module for further use
# 1. Used to display the transactions made by customers living in a given zip code for a given month and year. Order by day in descending order.

# %%
from tabulate import tabulate

# %%
def get_trxn_by_zip_mo_yr(zip, mo, yr):
    try:
        with connect_to_mysql() as cnx:
            cursor = cnx.cursor()
            cursor.execute("use creditcard_capstone")
            # use customer as main table here since we are filtering data using customer zip as the primary predicate
            query = f'''select cust.CUST_ZIP, cc.* 
                    from cdw_sapp_customer as cust 
                    left join cdw_sapp_credit_card as cc
                    on cc.cust_ssn = cust.ssn
                    where cust.cust_zip = {zip} and month(cc.timeid) = {mo} and year(cc.timeid) = {yr}
                    order by cc.timeid desc'''
            cursor.execute(query)
            data = cursor.fetchall()
            if data:
                headers = cursor.column_names
                # alternate: headers = [col[0] for col in cursor.description]
                # cursor.description returns something like df.printSchema() or df.columns in rows of tuples, hence header=the 1st column
                table = tabulate(data, headers=headers,
                                 tablefmt="pretty", stralign="left")
                print(table)
            else:
                print("Record not found.")

    except Error as e:
        print(e)


print("Query transaction details by customer zip code, month, and year.")
zip = input("Enter zip code: ")  # try 19438
mo = input("Enter month 'mm': ")  # try 02
yr = input("Enter year 'yyyy': ")  # try 2018
get_trxn_by_zip_mo_yr(zip, mo, yr)
# Out:
# Query transaction details by customer zip code, month, and year.
# +----------+------------------+------------+-----------+-------------+------------------+-------------------+----------------+
# | CUST_ZIP | CUST_CC_NO       | TIMEID     | CUST_SSN  | BRANCH_CODE | TRANSACTION_TYPE | TRANSACTION_VALUE | TRANSACTION_ID |
# +----------+------------------+------------+-----------+-------------+------------------+-------------------+----------------+
# | 19438    | 4210653360481256 | 2018-02-26 | 123455001 | 144         | Grocery          | 61.74             | 26068          |
# | 19438    | 4210653349028689 | 2018-02-24 | 123459988 | 89          | Healthcare       | 97.98             | 82             |
# | 19438    | 4210653338106818 | 2018-02-24 | 123458199 | 124         | Entertainment    | 46.33             | 8989           |
# | 19438    | 4210653327324219 | 2018-02-23 | 123458390 | 115         | Bills            | 22.09             | 7902           |
# | 19438    | 4210653354321803 | 2018-02-22 | 123459833 | 63          | Grocery          | 80.27             | 739            |
# | 19438    | 4210653360123603 | 2018-02-22 | 123452856 | 95          | Gas              | 14.02             | 37535          |
# | 19438    | 4210653360123603 | 2018-02-21 | 123452856 | 11          | Entertainment    | 20.15             | 37563          |
# | 19438    | 4210653364380528 | 2018-02-20 | 123451436 | 118         | Gas              | 16.72             | 44256          |
# | 19438    | 4210653327324219 | 2018-02-20 | 123458390 | 53          | Grocery          | 43.62             | 7858           |
# | 19438    | 4210653360481256 | 2018-02-19 | 123455001 | 58          | Entertainment    | 23.51             | 26064          |
# | 19438    | 4210653360481256 | 2018-02-19 | 123455001 | 74          | Bills            | 53.82             | 26080          |
# | 19438    | 4210653360123603 | 2018-02-17 | 123452856 | 1           | Education        | 66.45             | 37626          |
# | 19438    | 4210653364380528 | 2018-02-16 | 123451436 | 99          | Grocery          | 32.48             | 44254          |
# | 19438    | 4210653360123603 | 2018-02-16 | 123452856 | 39          | Gas              | 75.55             | 37608          |
# | 19438    | 4210653354321803 | 2018-02-16 | 123459833 | 7           | Education        | 88.57             | 716            |
# | 19438    | 4210653349028689 | 2018-02-15 | 123459988 | 27          | Entertainment    | 46.53             | 68             |
# | 19438    | 4210653379492990 | 2018-02-15 | 123453623 | 53          | Entertainment    | 26.52             | 33596          |
# | 19438    | 4210653327324219 | 2018-02-14 | 123458390 | 4           | Bills            | 66.66             | 7840           |
# | 19438    | 4210653349028689 | 2018-02-14 | 123459988 | 114         | Education        | 78.9              | 1              |
# | 19438    | 4210653360123603 | 2018-02-14 | 123452856 | 78          | Grocery          | 85.31             | 37583          |
# | 19438    | 4210653338106818 | 2018-02-12 | 123458199 | 136         | Entertainment    | 68.84             | 9003           |
# | 19438    | 4210653360123603 | 2018-02-11 | 123452856 | 81          | Gas              | 56.1              | 37558          |
# | 19438    | 4210653327324219 | 2018-02-09 | 123458390 | 37          | Bills            | 98.13             | 7863           |
# | 19438    | 4210653338106818 | 2018-02-08 | 123458199 | 123         | Healthcare       | 82.4              | 8987           |
# | 19438    | 4210653360481256 | 2018-02-08 | 123455001 | 89          | Gas              | 16.1              | 26094          |
# | 19438    | 4210653360123603 | 2018-02-08 | 123452856 | 72          | Test             | 33.8              | 37584          |
# | 19438    | 4210653338106818 | 2018-02-06 | 123458199 | 59          | Test             | 51.2              | 9029           |
# | 19438    | 4210653354321803 | 2018-02-06 | 123459833 | 121         | Bills            | 45.45             | 777            |
# | 19438    | 4210653354321803 | 2018-02-06 | 123459833 | 36          | Grocery          | 5.55              | 770            |
# | 19438    | 4210653360123603 | 2018-02-06 | 123452856 | 53          | Education        | 8.5               | 37618          |
# | 19438    | 4210653349028689 | 2018-02-06 | 123459988 | 175         | Test             | 12.43             | 87             |
# | 19438    | 4210653356092560 | 2018-02-05 | 123452595 | 53          | Healthcare       | 31.9              | 38630          |
# | 19438    | 4210653338106818 | 2018-02-04 | 123458199 | 53          | Healthcare       | 76.75             | 9001           |
# | 19438    | 4210653349028689 | 2018-02-03 | 123459988 | 59          | Healthcare       | 31.87             | 54             |
# | 19438    | 4210653354321803 | 2018-02-02 | 123459833 | 32          | Healthcare       | 40.15             | 778            |
# | 19438    | 4210653354321803 | 2018-02-02 | 123459833 | 39          | Grocery          | 12.72             | 715            |
# | 19438    | 4210653349028689 | 2018-02-02 | 123459988 | 11          | Education        | 91.2              | 90             |
# +----------+------------------+------------+-----------+-------------+------------------+-------------------+----------------+

# %% [markdown]
# 2. Used to display the number and total values of transactions for a given type.

# %%
def get_trxn_by_type(type):
    try:
        with connect_to_mysql() as cnx:
            cursor = cnx.cursor()
            cursor.execute("use creditcard_capstone")
            query = f'''select transaction_type as TRXN_TYPE, count(*) as TRXN_COUNT, round(sum(transaction_value),2) as TOTAL_TRXN_VAL
                    from cdw_sapp_credit_card 
                    where transaction_type = '{type}'
                    group by transaction_type'''
            cursor.execute(query)
            data = cursor.fetchall()
            if data:
                # cursor.description returns something like df.printSchema() or df.columns in rows of tuples, hence header=the 1st column
                headers = cursor.column_names
                table = tabulate(data, headers=headers,
                                 tablefmt="pretty", stralign="left")
                print(table)
            else:
                print("Record not found.")

    except Error as e:
        print(e)


print("Query transaction summary by type.")
type = input("Enter transaction type: ")  # try Gas
get_trxn_by_type(type)
# Out:
# Query transaction summary by type.
# +-----------+------------+----------------+
# | TRXN_TYPE | TRXN_COUNT | TOTAL_TRXN_VAL |
# +-----------+------------+----------------+
# | Gas       | 6605       | 336059.26      |
# +-----------+------------+----------------+

# %% [markdown]
# 3. Used to display the total number and total values of transactions for branches in a given state.

# %%
def get_trxn_by_branch(state):
    try:
        with connect_to_mysql() as cnx:
            cursor = cnx.cursor()
            cursor.execute("use creditcard_capstone")
            # use branch as main table since state is the primary predicate here
            query = f'''select branch_state as BRANCH_STATE, br.branch_code as BRANCH_CODE, branch_name as BRANCH_NAME, count(br.branch_code) as TRXN_COUNT, round(sum(transaction_value),2) as TOTAL_TRXN_VAL 
                    from cdw_sapp_branch as br
                    left join cdw_sapp_credit_card as cc
                    on br.branch_code = cc.branch_code
                    where branch_state = '{state}'
                    group by br.branch_code, branch_name
                    order by TOTAL_TRXN_VAL desc'''
            cursor.execute(query)
            data = cursor.fetchall()
            if data:
                # cursor.description returns something like df.printSchema() or df.columns in rows of tuples, hence header=the 1st column
                headers = cursor.column_names
                table = tabulate(data, headers=headers,
                                 tablefmt="pretty", stralign="left")
                print(table)
            else:
                print("Record not found.")

    except Error as e:
        print(e)


print("Query bank transaction summary by state.")
state = input("Enter state name (2 letters): ")  # try CA
get_trxn_by_branch(state)
# Out:
# Query bank transaction summary by state.
# +--------------+-------------+--------------+------------+----------------+
# | BRANCH_STATE | BRANCH_CODE | BRANCH_NAME  | TRXN_COUNT | TOTAL_TRXN_VAL |
# +--------------+-------------+--------------+------------+----------------+
# | CA           | 23          | Example Bank | 434        | 22583.27       |
# | CA           | 54          | Example Bank | 412        | 21261.37       |
# | CA           | 168         | Example Bank | 409        | 20757.48       |
# | CA           | 121         | Example Bank | 398        | 20571.75       |
# | CA           | 139         | Example Bank | 398        | 19735.83       |
# | CA           | 29          | Example Bank | 373        | 19112.13       |
# +--------------+-------------+--------------+------------+----------------+

# %% [markdown]
# 2.2 - Customer Details Module
# 1. Used to check the existing account details of a customer.

# %%
def get_acct_by_cust(ssn):
    try:
        with connect_to_mysql() as cnx:
            cursor = cnx.cursor()
            cursor.execute("use creditcard_capstone")
            query = f'''select * from cdw_sapp_credit_card where cust_ssn = '{ssn}' order by timeid desc'''
            cursor.execute(query)
            trxn = cursor.fetchall()
            if trxn:
                # print acct trxn details
                t_headers = cursor.column_names
                trxn_table = tabulate(
                    trxn, headers=t_headers, tablefmt="pretty", stralign="left")
                print(trxn_table)
                # print acct holder info
                query = f'''select * from cdw_sapp_customer where ssn = '{ssn}' order by last_updated desc'''
                cursor.execute(query)
                cust = cursor.fetchall()
                c_headers = cursor.column_names
                cust_table = tabulate(
                    cust, headers=c_headers, tablefmt="pretty", stralign="left")
                print(cust_table)
            else:
                print("Record not found.")

    except Error as e:
        print(e)


print("Query account details by customer SSN.")
ssn = input("Enter customer SSN: ")  # try 123459988
get_acct_by_cust(ssn)
# Out:
# Query account details by customer SSN.
# +------------------+------------+-----------+-------------+------------------+-------------------+----------------+
# | CUST_CC_NO       | TIMEID     | CUST_SSN  | BRANCH_CODE | TRANSACTION_TYPE | TRANSACTION_VALUE | TRANSACTION_ID |
# +------------------+------------+-----------+-------------+------------------+-------------------+----------------+
# | 4210653349028689 | 2018-12-24 | 123459988 | 17          | Gas              | 42.71             | 12             |
# | 4210653349028689 | 2018-12-22 | 123459988 | 121         | Education        | 43.08             | 63             |
# | 4210653349028689 | 2018-12-21 | 123459988 | 158         | Healthcare       | 30.58             | 55             |
# | 4210653349028689 | 2018-12-18 | 123459988 | 42          | Gas              | 38.07             | 75             |
# | 4210653349028689 | 2018-12-14 | 123459988 | 19          | Test             | 82.05             | 27             |
# | 4210653349028689 | 2018-12-12 | 123459988 | 66          | Education        | 13.34             | 32             |
# | 4210653349028689 | 2018-12-09 | 123459988 | 80          | Entertainment    | 15.89             | 52             |
# | 4210653349028689 | 2018-12-04 | 123459988 | 29          | Gas              | 17.03             | 30             |
# | 4210653349028689 | 2018-11-28 | 123459988 | 1           | Bills            | 53.03             | 77             |
# | 4210653349028689 | 2018-11-27 | 123459988 | 126         | Bills            | 1.32              | 57             |
# | 4210653349028689 | 2018-11-20 | 123459988 | 27          | Bills            | 30.95             | 42             |
# | 4210653349028689 | 2018-11-13 | 123459988 | 36          | Healthcare       | 79.91             | 44             |
# | 4210653349028689 | 2018-11-11 | 123459988 | 32          | Healthcare       | 60.9              | 85             |
# | 4210653349028689 | 2018-11-09 | 123459988 | 72          | Entertainment    | 53.03             | 34             |
# | 4210653349028689 | 2018-11-05 | 123459988 | 109         | Bills            | 7.62              | 86             |
# | 4210653349028689 | 2018-10-25 | 123459988 | 43          | Education        | 92.47             | 80             |
# | 4210653349028689 | 2018-10-25 | 123459988 | 63          | Gas              | 35.29             | 67             |
# | 4210653349028689 | 2018-10-24 | 123459988 | 123         | Grocery          | 54.49             | 31             |
# | 4210653349028689 | 2018-10-23 | 123459988 | 156         | Education        | 10.56             | 21             |
# | 4210653349028689 | 2018-10-20 | 123459988 | 117         | Healthcare       | 24.37             | 33             |
# | 4210653349028689 | 2018-10-14 | 123459988 | 7           | Grocery          | 9.49              | 29             |
# | 4210653349028689 | 2018-10-10 | 123459988 | 93          | Gas              | 3.59              | 5              |
# | 4210653349028689 | 2018-10-08 | 123459988 | 78          | Bills            | 34.34             | 20             |
# | 4210653349028689 | 2018-10-05 | 123459988 | 70          | Entertainment    | 46.84             | 39             |
# | 4210653349028689 | 2018-09-28 | 123459988 | 3           | Test             | 27.04             | 17             |
# | 4210653349028689 | 2018-09-28 | 123459988 | 32          | Education        | 62.82             | 36             |
# | 4210653349028689 | 2018-09-25 | 123459988 | 79          | Bills            | 70.25             | 84             |
# | 4210653349028689 | 2018-09-22 | 123459988 | 70          | Gas              | 84.13             | 61             |
# | 4210653349028689 | 2018-09-18 | 123459988 | 60          | Healthcare       | 89.81             | 64             |
# | 4210653349028689 | 2018-09-09 | 123459988 | 95          | Test             | 96.55             | 35             |
# | 4210653349028689 | 2018-09-08 | 123459988 | 124         | Healthcare       | 20.81             | 45             |
# | 4210653349028689 | 2018-09-06 | 123459988 | 158         | Education        | 63.08             | 38             |
# | 4210653349028689 | 2018-09-03 | 123459988 | 83          | Bills            | 100.38            | 10             |
# | 4210653349028689 | 2018-09-01 | 123459988 | 59          | Entertainment    | 97.64             | 91             |
# | 4210653349028689 | 2018-08-26 | 123459988 | 69          | Healthcare       | 26.34             | 49             |
# | 4210653349028689 | 2018-08-25 | 123459988 | 175         | Test             | 17.12             | 88             |
# | 4210653349028689 | 2018-08-21 | 123459988 | 52          | Gas              | 98.75             | 11             |
# | 4210653349028689 | 2018-08-13 | 123459988 | 20          | Education        | 6.7               | 22             |
# | 4210653349028689 | 2018-08-11 | 123459988 | 63          | Education        | 82.11             | 66             |
# | 4210653349028689 | 2018-08-09 | 123459988 | 59          | Bills            | 13.72             | 58             |
# | 4210653349028689 | 2018-08-08 | 123459988 | 23          | Gas              | 95.39             | 8              |
# | 4210653349028689 | 2018-08-06 | 123459988 | 43          | Healthcare       | 98.78             | 28             |
# | 4210653349028689 | 2018-08-03 | 123459988 | 66          | Education        | 58.25             | 92             |
# | 4210653349028689 | 2018-07-17 | 123459988 | 48          | Education        | 8.08              | 72             |
# | 4210653349028689 | 2018-07-12 | 123459988 | 118         | Grocery          | 57.52             | 89             |
# | 4210653349028689 | 2018-07-09 | 123459988 | 50          | Bills            | 72.72             | 94             |
# | 4210653349028689 | 2018-07-08 | 123459988 | 160         | Grocery          | 56.7              | 3              |
# | 4210653349028689 | 2018-07-06 | 123459988 | 9           | Test             | 70.63             | 16             |
# | 4210653349028689 | 2018-07-04 | 123459988 | 135         | Entertainment    | 88.75             | 18             |
# | 4210653349028689 | 2018-07-02 | 123459988 | 99          | Gas              | 41.06             | 93             |
# | 4210653349028689 | 2018-06-24 | 123459988 | 74          | Entertainment    | 72.17             | 60             |
# | 4210653349028689 | 2018-06-13 | 123459988 | 53          | Gas              | 66.48             | 79             |
# | 4210653349028689 | 2018-06-12 | 123459988 | 9           | Bills            | 87.58             | 71             |
# | 4210653349028689 | 2018-06-07 | 123459988 | 31          | Test             | 93.2              | 69             |
# | 4210653349028689 | 2018-06-04 | 123459988 | 79          | Gas              | 83.33             | 43             |
# | 4210653349028689 | 2018-05-28 | 123459988 | 164         | Education        | 6.89              | 6              |
# | 4210653349028689 | 2018-05-19 | 123459988 | 119         | Entertainment    | 43.39             | 7              |
# | 4210653349028689 | 2018-05-17 | 123459988 | 123         | Bills            | 29.0              | 15             |
# | 4210653349028689 | 2018-05-12 | 123459988 | 20          | Education        | 3.79              | 48             |
# | 4210653349028689 | 2018-05-11 | 123459988 | 54          | Test             | 32.81             | 24             |
# | 4210653349028689 | 2018-05-11 | 123459988 | 121         | Test             | 86.3              | 26             |
# | 4210653349028689 | 2018-04-28 | 123459988 | 50          | Grocery          | 41.62             | 47             |
# | 4210653349028689 | 2018-04-27 | 123459988 | 139         | Grocery          | 61.4              | 70             |
# | 4210653349028689 | 2018-04-24 | 123459988 | 103         | Test             | 77.02             | 19             |
# | 4210653349028689 | 2018-04-19 | 123459988 | 114         | Entertainment    | 59.73             | 4              |
# | 4210653349028689 | 2018-04-15 | 123459988 | 50          | Bills            | 17.81             | 14             |
# | 4210653349028689 | 2018-04-14 | 123459988 | 73          | Education        | 31.89             | 78             |
# | 4210653349028689 | 2018-04-14 | 123459988 | 43          | Grocery          | 16.99             | 53             |
# | 4210653349028689 | 2018-04-12 | 123459988 | 104         | Education        | 73.99             | 37             |
# | 4210653349028689 | 2018-04-03 | 123459988 | 80          | Grocery          | 40.24             | 13             |
# | 4210653349028689 | 2018-03-27 | 123459988 | 144         | Bills            | 45.93             | 74             |
# | 4210653349028689 | 2018-03-20 | 123459988 | 35          | Entertainment    | 14.24             | 2              |
# | 4210653349028689 | 2018-03-20 | 123459988 | 123         | Test             | 51.91             | 62             |
# | 4210653349028689 | 2018-03-18 | 123459988 | 166         | Entertainment    | 93.26             | 9              |
# | 4210653349028689 | 2018-03-17 | 123459988 | 44          | Bills            | 7.97              | 23             |
# | 4210653349028689 | 2018-03-16 | 123459988 | 49          | Gas              | 51.93             | 76             |
# | 4210653349028689 | 2018-03-16 | 123459988 | 156         | Healthcare       | 45.55             | 59             |
# | 4210653349028689 | 2018-03-15 | 123459988 | 99          | Entertainment    | 81.4              | 81             |
# | 4210653349028689 | 2018-03-07 | 123459988 | 145         | Entertainment    | 92.84             | 73             |
# | 4210653349028689 | 2018-03-07 | 123459988 | 26          | Education        | 25.01             | 41             |
# | 4210653349028689 | 2018-03-04 | 123459988 | 93          | Gas              | 73.45             | 51             |
# | 4210653349028689 | 2018-03-04 | 123459988 | 17          | Bills            | 55.4              | 83             |
# | 4210653349028689 | 2018-03-03 | 123459988 | 119         | Entertainment    | 35.02             | 25             |
# | 4210653349028689 | 2018-02-24 | 123459988 | 89          | Healthcare       | 97.98             | 82             |
# | 4210653349028689 | 2018-02-15 | 123459988 | 27          | Entertainment    | 46.53             | 68             |
# | 4210653349028689 | 2018-02-14 | 123459988 | 114         | Education        | 78.9              | 1              |
# | 4210653349028689 | 2018-02-06 | 123459988 | 175         | Test             | 12.43             | 87             |
# | 4210653349028689 | 2018-02-03 | 123459988 | 59          | Healthcare       | 31.87             | 54             |
# | 4210653349028689 | 2018-02-02 | 123459988 | 11          | Education        | 91.2              | 90             |
# | 4210653349028689 | 2018-01-25 | 123459988 | 31          | Grocery          | 56.84             | 65             |
# | 4210653349028689 | 2018-01-21 | 123459988 | 104         | Bills            | 4.95              | 46             |
# | 4210653349028689 | 2018-01-16 | 123459988 | 69          | Entertainment    | 96.29             | 40             |
# | 4210653349028689 | 2018-01-11 | 123459988 | 27          | Grocery          | 4.19              | 56             |
# | 4210653349028689 | 2018-01-02 | 123459988 | 76          | Entertainment    | 53.49             | 50             |
# +------------------+------------+-----------+-------------+------------------+-------------------+----------------+
# +-----------+------------+-------------+-----------+------------------+---------------------+--------------+------------+---------------+----------+---------------+---------------------+---------------------+
# | SSN       | FIRST_NAME | MIDDLE_NAME | LAST_NAME | CREDIT_CARD_NO   | FULL_STREET_ADDRESS | CUST_CITY    | CUST_STATE | CUST_COUNTRY  | CUST_ZIP | CUST_PHONE    | CUST_EMAIL          | LAST_UPDATED        |
# +-----------+------------+-------------+-----------+------------------+---------------------+--------------+------------+---------------+----------+---------------+---------------------+---------------------+
# | 123459988 | Amalia     | hal         | Campos    | 4210653349028689 | Valley Drive, 774   | Harleysville | PA         | United States | 19438    | (XXX)123-6163 | ACampos@example.com | 2018-04-21 09:49:02 |
# +-----------+------------+-------------+-----------+------------------+---------------------+--------------+------------+---------------+----------+---------------+---------------------+---------------------+

# %% [markdown]
# 2. Used to modify the existing account details of a customer.

# %%
# trxn data is usually auto-captured and non-editable, hence we'll only modify acct holder info here
def modify_acct(ssn, item, update):
    try:
        with connect_to_mysql() as cnx:
            # need to add buffered=True here, otherwise commit will fail and output 'unread result found'
            cursor = cnx.cursor(buffered=True)
            cursor.execute("use creditcard_capstone")
            cursor.execute("select * from cdw_sapp_customer limit 1")
            headers = cursor.column_names  # prints out a tuple of column names
            print(headers)
            # ('SSN', 'FIRST_NAME', 'MIDDLE_NAME', 'LAST_NAME', 'CREDIT_CARD_NO', 'FULL_STREET_ADDRESS', 'CUST_CITY', 'CUST_STATE', 'CUST_COUNTRY', 'CUST_ZIP', 'CUST_PHONE', 'CUST_EMAIL', 'LAST_UPDATED')
            print(item)
            if item in headers and item != 'SSN':
                query = f'''update cdw_sapp_customer set {item} = '{update}' where ssn = '{ssn}' '''
                print(query)
                cursor.execute(query)
                # commit change to db
                cnx.commit()
                print(cursor.rowcount, "record(s) affected")
                cursor.execute(f'''select * from cdw_sapp_customer where ssn = '{ssn}' ''')
                data = cursor.fetchall()
                table = tabulate(data, headers=headers, tablefmt="pretty", stralign="left")
                print(table)
            else:
                print("Commit failed. Item selected not found.")

    except Error as e:
        cnx.rollback()
        print(e)
        # rollback in case there is any error

print("Modify existing account details by customer SSN.")
ssn = input("Enter customer SSN: ")  # try 123459988
item = input("Select the item you want to modify(SSN excluded): ").upper() # try last_name
update = input("Enter new content: ")  # try newchange
modify_acct(ssn, item, update)
# Out:
# ('SSN', 'FIRST_NAME', 'MIDDLE_NAME', 'LAST_NAME', 'CREDIT_CARD_NO', 'FULL_STREET_ADDRESS', 'CUST_CITY', 'CUST_STATE', 'CUST_COUNTRY', 'CUST_ZIP', 'CUST_PHONE', 'CUST_EMAIL', 'LAST_UPDATED')
# LAST_NAME
# update cdw_sapp_customer set LAST_NAME = 'Campos' where ssn = '123459988'
# 1 record(s) affected
# +-----------+------------+-------------+-----------+------------------+---------------------+--------------+------------+---------------+----------+---------------+---------------------+---------------------+
# | SSN       | FIRST_NAME | MIDDLE_NAME | LAST_NAME | CREDIT_CARD_NO   | FULL_STREET_ADDRESS | CUST_CITY    | CUST_STATE | CUST_COUNTRY  | CUST_ZIP | CUST_PHONE    | CUST_EMAIL          | LAST_UPDATED        |
# +-----------+------------+-------------+-----------+------------------+---------------------+--------------+------------+---------------+----------+---------------+---------------------+---------------------+
# | 123459988 | Amalia     | hal         | Campos    | 4210653349028689 | Valley Drive, 774   | Harleysville | PA         | United States | 19438    | (XXX)123-6163 | ACampos@example.com | 2018-04-21 09:49:02 |
# +-----------+------------+-------------+-----------+------------------+---------------------+--------------+------------+---------------+----------+---------------+---------------------+---------------------+

# %% [markdown]
# 3. Used to generate a monthly bill for a credit card number for a given month and year.

# %%
def generate_bill_by_ccno_mo_yr(cc_no, mo, yr):
    try:
        with connect_to_mysql() as cnx:
            cursor = cnx.cursor()
            cursor.execute("use creditcard_capstone")
            query = f'''select * from cdw_sapp_credit_card 
                    where cust_cc_no = {cc_no} and month(timeid) = {mo} and year(timeid) = {yr} 
                    order by timeid desc'''
            cursor.execute(query)
            data = cursor.fetchall()
            if data:
                # print monthly bill
                headers = cursor.column_names
                table = tabulate(data, headers=headers,
                                 tablefmt="pretty", stralign="left")
                print(table)
                # print customer info
                query = f'''select distinct * from cdw_sapp_customer where credit_card_no = {cc_no}'''
                cursor.execute(query)
                cust_info = cursor.fetchall()
                headers = cursor.column_names
                cust_table = tabulate(
                    cust_info, headers=headers, tablefmt="pretty", stralign="left")
                print(cust_table)
            else:
                print("Record not found.")

    except Error as e:
        print(e)


print("Query monthly bill by credit card number, month, and year.")
cc_no = input("Enter credit card number:")  # try 4210653349028689
mo = input("Enter month 'mm':")  # try 12
yr = input("Enter month 'yyyy':")  # try 2018
generate_bill_by_ccno_mo_yr(cc_no, mo, yr)
# Out:
# Query monthly bill by credit card number, month, and year.
# +------------------+------------+-----------+-------------+------------------+-------------------+----------------+
# | CUST_CC_NO       | TIMEID     | CUST_SSN  | BRANCH_CODE | TRANSACTION_TYPE | TRANSACTION_VALUE | TRANSACTION_ID |
# +------------------+------------+-----------+-------------+------------------+-------------------+----------------+
# | 4210653349028689 | 2018-12-24 | 123459988 | 17          | Gas              | 42.71             | 12             |
# | 4210653349028689 | 2018-12-22 | 123459988 | 121         | Education        | 43.08             | 63             |
# | 4210653349028689 | 2018-12-21 | 123459988 | 158         | Healthcare       | 30.58             | 55             |
# | 4210653349028689 | 2018-12-18 | 123459988 | 42          | Gas              | 38.07             | 75             |
# | 4210653349028689 | 2018-12-14 | 123459988 | 19          | Test             | 82.05             | 27             |
# | 4210653349028689 | 2018-12-12 | 123459988 | 66          | Education        | 13.34             | 32             |
# | 4210653349028689 | 2018-12-09 | 123459988 | 80          | Entertainment    | 15.89             | 52             |
# | 4210653349028689 | 2018-12-04 | 123459988 | 29          | Gas              | 17.03             | 30             |
# +------------------+------------+-----------+-------------+------------------+-------------------+----------------+
# +-----------+------------+-------------+-----------+------------------+---------------------+--------------+------------+---------------+----------+---------------+---------------------+---------------------+
# | SSN       | FIRST_NAME | MIDDLE_NAME | LAST_NAME | CREDIT_CARD_NO   | FULL_STREET_ADDRESS | CUST_CITY    | CUST_STATE | CUST_COUNTRY  | CUST_ZIP | CUST_PHONE    | CUST_EMAIL          | LAST_UPDATED        |
# +-----------+------------+-------------+-----------+------------------+---------------------+--------------+------------+---------------+----------+---------------+---------------------+---------------------+
# | 123459988 | Amalia     | hal         | Campos    | 4210653349028689 | Valley Drive, 774   | Harleysville | PA         | United States | 19438    | (XXX)123-6163 | ACampos@example.com | 2018-04-21 09:49:02 |
# +-----------+------------+-------------+-----------+------------------+---------------------+--------------+------------+---------------+----------+---------------+---------------------+---------------------+

# %% [markdown]
# 4. Used to display the transactions made by a customer between two dates. Order by year, month, and day in descending order.

# %%
def get_trxn_by_ssn_and_date(ssn, d1, d2):
    try:
        with connect_to_mysql() as cnx:
            cursor = cnx.cursor()
            cursor.execute("use creditcard_capstone")
            query = f'''select * from cdw_sapp_credit_card 
                    where cust_ssn = {ssn} and timeid between '{d1}' and '{d2}'
                    order by timeid desc'''
            cursor.execute(query)
            data = cursor.fetchall()
            if data:
                headers = cursor.column_names
                table = tabulate(data, headers=headers,
                                 tablefmt="pretty", stralign="left")
                print(table)
            else:
                print("Record not found.")

    except Error as e:
        print(e)


print("Query transaction details by customer SSN and date range.")
ssn = input("Enter customer SSN: ")  # try 123459988
d1 = input("From (yyyy-mm-dd): ")  # try 2018-12-04
d2 = input("To (yyyy-mm-dd): ")  # try 2018-12-24
get_trxn_by_ssn_and_date(ssn, d1, d2)
# Out:
# Query transaction details by customer SSN and date range.
# +------------------+------------+-----------+-------------+------------------+-------------------+----------------+
# | CUST_CC_NO       | TIMEID     | CUST_SSN  | BRANCH_CODE | TRANSACTION_TYPE | TRANSACTION_VALUE | TRANSACTION_ID |
# +------------------+------------+-----------+-------------+------------------+-------------------+----------------+
# | 4210653349028689 | 2018-12-24 | 123459988 | 17          | Gas              | 42.71             | 12             |
# | 4210653349028689 | 2018-12-22 | 123459988 | 121         | Education        | 43.08             | 63             |
# | 4210653349028689 | 2018-12-21 | 123459988 | 158         | Healthcare       | 30.58             | 55             |
# | 4210653349028689 | 2018-12-18 | 123459988 | 42          | Gas              | 38.07             | 75             |
# | 4210653349028689 | 2018-12-14 | 123459988 | 19          | Test             | 82.05             | 27             |
# | 4210653349028689 | 2018-12-12 | 123459988 | 66          | Education        | 13.34             | 32             |
# | 4210653349028689 | 2018-12-09 | 123459988 | 80          | Entertainment    | 15.89             | 52             |
# | 4210653349028689 | 2018-12-04 | 123459988 | 29          | Gas              | 17.03             | 30             |
# +------------------+------------+-----------+-------------+------------------+-------------------+----------------+

# %% [markdown]
# ### 3. Functional Requirements - Data Analysis and Visualization
# After data is loaded into the database, users can make changes from the front end, and they can also view data from the front end. Now, the business analyst team wants to analyze and visualize the data.
#
# Use Python libraries for the below requirements:
#
# 3.1 - Find and plot which transaction type has the highest transaction count.
#
# Note: Save a copy of the visualization to a folder in your github, making sure it is PROPERLY NAMED!

# %%
import matplotlib.pyplot as plt
from matplotlib import style

# %%
def view_trxn_type():
    try:
        with connect_to_mysql() as cnx:
            cursor = cnx.cursor()
            cursor.execute("use creditcard_capstone")
            query = '''select transaction_type as TRXN_TYPE, count(distinct transaction_id) as NUM_TRXNS
                    from cdw_sapp_credit_card
                    group by TRXN_TYPE
                    order by NUM_TRXNS desc'''
            cursor.execute(query)
            data = cursor.fetchall()
            if data:
                headers = cursor.column_names
                table = tabulate(data, headers=headers,
                                 tablefmt="pretty", stralign="left")
                print(table)
                # create data visualization
                trxn_type = [row[0] for row in data]  # pie labels
                trxn_count = [row[1] for row in data]  # pie sizes
                plt.style.use('ggplot')
                plt.figure(3.1, figsize=(6, 4.5), layout='tight')
                # make a slice pop out
                explode = (0.1, 0, 0, 0, 0, 0, 0)
                plt.pie(trxn_count, explode=explode, labels=trxn_type,
                        autopct='%1.1f%%', shadow=True)
                plt.title("Trends in Credit Card Spending 2018",
                          fontsize=16, fontweight='bold', pad=25)
                plt.axis('equal')
                plt.show()

    except Error as e:
        print(e)


view_trxn_type()
# Out:
# +---------------+-----------+
# | TRXN_TYPE     | NUM_TRXNS |
# +---------------+-----------+
# | Bills         | 6861      |
# | Healthcare    | 6723      |
# | Test          | 6683      |
# | Education     | 6638      |
# | Entertainment | 6635      |
# | Gas           | 6605      |
# | Grocery       | 6549      |
# +---------------+-----------+

# %% [markdown]
# 3.2 - Find and plot which state has a high number of customers.
#
# Note: Save a copy of the visualization to a folder in your github, making sure it is PROPERLY NAMED!

# %%
def view_client_volume():
    try:
        with connect_to_mysql() as cnx:
            cursor = cnx.cursor()
            cursor.execute("use creditcard_capstone")
            query = '''select br.branch_state as BRANCH_STATE, count(distinct cc.cust_ssn) as NUM_CUST
                    from cdw_sapp_branch br
                    right join cdw_sapp_credit_card cc on br.branch_code = cc.branch_code
                    group by BRANCH_STATE
                    order by NUM_CUST desc'''
            cursor.execute(query)
            data = cursor.fetchall()
            if data:
                headers = cursor.column_names
                table = tabulate(data, headers=headers,
                                 tablefmt="pretty", stralign="left")
                print(table)
                # create data visualization
                state = [row[0] for row in data]  # y-axis
                cust = [row[1] for row in data]  # x-axis
                plt.style.use('ggplot')
                plt.figure(3.2, figsize=(8.5, 6), layout='tight')
                plt.barh(state, cust, height=0.6)
                plt.title("Number of Bank Customers by State 2018",
                          fontsize=16, fontweight='bold', pad=15)
                plt.xlabel("Client Volume", fontsize=11)
                plt.xlim(0, 1000)
                plt.yticks(fontsize=10)
                # Invert the y-axis for ascending order from bottom to top
                plt.gca().invert_yaxis()
                # add customer count as labels on top of the bars
                for index, value in enumerate(cust):
                    plt.text(value, index, str(value), va='center', fontsize=8)
                plt.show()

    except Error as e:
        print(e)


view_client_volume()
# Out:
# +--------------+----------+
# | BRANCH_STATE | NUM_CUST |
# +--------------+----------+
# | PA           | 868      |
# | FL           | 843      |
# | NY           | 840      |
# | MI           | 824      |
# | OH           | 804      |
# | IL           | 784      |
# | CA           | 782      |
# | NJ           | 754      |
# | GA           | 743      |
# | TX           | 735      |
# | MD           | 722      |
# | NC           | 711      |
# | IA           | 692      |
# | WI           | 691      |
# | SC           | 633      |
# | MS           | 627      |
# | MN           | 574      |
# | MA           | 519      |
# | VA           | 514      |
# | WA           | 511      |
# | IN           | 509      |
# | CT           | 500      |
# | KY           | 486      |
# | AR           | 338      |
# | MT           | 307      |
# | AL           | 291      |
# +--------------+----------+

# %% [markdown]
# 3.3 - Find and plot the sum of all transactions for the top 10 customers, and which customer has the highest transaction amount.
# Hint (use CUST_SSN).
#
# Note: Save a copy of the visualization to a folder in your github, making sure it is PROPERLY NAMED!

# %%
def view_top10_trxns():
    try:
        with connect_to_mysql() as cnx:
            cursor = cnx.cursor()
            cursor.execute("use creditcard_capstone")
            query = '''select CUST_SSN, concat(left(first_name, 1), left(last_name, 1)) as CUST, count(*) as NUM_TRXNS, round(sum(transaction_value),2) as TOTAL_TRXN_AMT
                    from cdw_sapp_credit_card cc
                    left join cdw_sapp_customer cust
                    on cc.cust_ssn = cust.ssn
                    group by CUST_SSN, CUST
                    order by TOTAL_TRXN_AMT desc, NUM_TRXNS desc
                    limit 10'''
            cursor.execute(query)
            data = cursor.fetchall()
            if data:
                headers = cursor.column_names
                table = tabulate(data, headers=headers,
                                 tablefmt="pretty", stralign="left")
                print(table)
                # create data visualization
                cust = [row[1] for row in data]  # x-axis
                trxn_amt = [row[3] for row in data]  # y-axis
                plt.style.use('ggplot')
                plt.figure(3.3, figsize=(9, 5.5))
                plt.bar(cust, trxn_amt, width=0.6)
                plt.title("Top 10 Clients with Highest Credit Card Spending in 2018",
                          fontsize=16, fontweight='bold', pad=18)
                plt.ylabel("Annual Spending", fontsize=10)
                plt.ylim(0, 7000)
                # add spending amounts as labels on top of the bars
                for x, y in zip(cust, trxn_amt):
                    plt.text(x, y, f"${round(y)}",
                             ha="center", va="bottom", fontsize=9)
                plt.show()

    except Error as e:
        print(e)


view_top10_trxns()
# Out:
# +-----------+------+-----------+----------------+
# | CUST_SSN  | CUST | NUM_TRXNS | TOTAL_TRXN_AMT |
# +-----------+------+-----------+----------------+
# | 123451125 | TD   | 96        | 5633.07        |
# | 123452783 | JB   | 97        | 5548.14        |
# | 123453486 | PM   | 95        | 5476.08        |
# | 123458668 | TV   | 99        | 5314.97        |
# | 123456678 | BP   | 99        | 5261.03        |
# | 123452026 | JM   | 98        | 5241.18        |
# | 123452518 | AH   | 91        | 5223.96        |
# | 123454933 | ME   | 96        | 5203.08        |
# | 123457547 | AV   | 91        | 5149.75        |
# | 123452085 | CS   | 94        | 5133.29        |
# +-----------+------+-----------+----------------+

# %% [markdown]
# `Overview of LOAN Application Data API`
#
# Banks deal in all home loans. They have a presence across all urban, semi-urban, and rural areas. Customers first apply for a home loan; after that, a company will validate the customer's eligibility for a loan.
#
# Banks want to automate the loan eligibility process (in real time) based on customer details provided while filling out the online application form. These details are Gender, Marital Status, Education, Number of Dependents, Income, Loan Amount, Credit History, and others. To automate this process, they have the task of identifying the customer segments to those who are eligible for loan amounts so that they can specifically target these customers. Here they have provided a partial dataset.
#
# API Endpoint: https://raw.githubusercontent.com/platformps/LoanDataset/main/loan_data.json
#
# The above URL allows you to access information for loan application information. This dataset has all of the required fields for a loan application. You can access data from a REST API by sending an HTTP request and processing the response.

# %% [markdown]
# ### 4. Functional Requirements - LOAN Application Dataset
# 4.1 - Create a Python program to GET (consume) data from the above API endpoint for the loan application dataset.
#
# 4.2 - Find the status code of the above API endpoint. Hint: status code could be 200 (request succeeded), 400 (bad request), 404 (unauthorized), 401 (not found).

# %%
import requests
import json
import pprint as pp

# %%
url = "https://raw.githubusercontent.com/platformps/LoanDataset/main/loan_data.json"
response = requests.get(url)
print("Response status code: ", response.status_code)
if response.status_code == 200:
    data = response.json()
    pp.pprint(data)
# Out:
# Response status code:  200
# [{'Application_ID': 'LP001002',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'medium',
#   'Married': 'No',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001003',
#   'Application_Status': 'N',
#   'Credit_History': 1,
#   'Dependents': '1',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'medium',
#   'Married': 'Yes',
#   'Property_Area': 'Rural',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001005',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'Yes'},
#  {'Application_ID': 'LP001006',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Not Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001008',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'medium',
#   'Married': 'No',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001011',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '2',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'medium',
#   'Married': 'Yes',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'Yes'},
#  {'Application_ID': 'LP001013',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Not Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001014',
#   'Application_Status': 'N',
#   'Credit_History': 0,
#   'Dependents': '3+',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001018',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '2',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'medium',
#   'Married': 'Yes',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001020',
#   'Application_Status': 'N',
#   'Credit_History': 1,
#   'Dependents': '1',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'high',
#   'Married': 'Yes',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001024',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '2',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001028',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '2',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001029',
#   'Application_Status': 'N',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'No',
#   'Property_Area': 'Rural',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001030',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '2',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001032',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'medium',
#   'Married': 'No',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001036',
#   'Application_Status': 'N',
#   'Credit_History': 0,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Female',
#   'Income': 'low',
#   'Married': 'No',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001038',
#   'Application_Status': 'N',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Not Graduate',
#   'Gender': 'Male',
#   'Income': 'medium',
#   'Married': 'Yes',
#   'Property_Area': 'Rural',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001043',
#   'Application_Status': 'N',
#   'Credit_History': 0,
#   'Dependents': '0',
#   'Education': 'Not Graduate',
#   'Gender': 'Male',
#   'Income': 'medium',
#   'Married': 'Yes',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001046',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '1',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'medium',
#   'Married': 'Yes',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001047',
#   'Application_Status': 'N',
#   'Credit_History': 0,
#   'Dependents': '0',
#   'Education': 'Not Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001066',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'medium',
#   'Married': 'Yes',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'Yes'},
#  {'Application_ID': 'LP001068',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001073',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '2',
#   'Education': 'Not Graduate',
#   'Gender': 'Male',
#   'Income': 'medium',
#   'Married': 'Yes',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001086',
#   'Application_Status': 'N',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Not Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'No',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001095',
#   'Application_Status': 'N',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'No',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001097',
#   'Application_Status': 'N',
#   'Credit_History': 1,
#   'Dependents': '1',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'medium',
#   'Married': 'No',
#   'Property_Area': 'Rural',
#   'Self_Employed': 'Yes'},
#  {'Application_ID': 'LP001098',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001100',
#   'Application_Status': 'N',
#   'Credit_History': 1,
#   'Dependents': '3+',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'high',
#   'Married': 'No',
#   'Property_Area': 'Rural',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001106',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001109',
#   'Application_Status': 'N',
#   'Credit_History': 0,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001112',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Female',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001114',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'medium',
#   'Married': 'No',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001116',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Not Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'No',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001119',
#   'Application_Status': 'N',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'No',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001120',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'No',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001131',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001136',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Not Graduate',
#   'Gender': 'Male',
#   'Income': 'medium',
#   'Married': 'Yes',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'Yes'},
#  {'Application_ID': 'LP001137',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Female',
#   'Income': 'low',
#   'Married': 'No',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001138',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '1',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'medium',
#   'Married': 'Yes',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001144',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'medium',
#   'Married': 'Yes',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001146',
#   'Application_Status': 'N',
#   'Credit_History': 0,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Female',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001151',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Female',
#   'Income': 'medium',
#   'Married': 'No',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001155',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Not Graduate',
#   'Gender': 'Female',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001157',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Female',
#   'Income': 'low',
#   'Married': 'No',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001164',
#   'Application_Status': 'N',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Female',
#   'Income': 'medium',
#   'Married': 'No',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001179',
#   'Application_Status': 'N',
#   'Credit_History': 1,
#   'Dependents': '2',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'medium',
#   'Married': 'Yes',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001186',
#   'Application_Status': 'N',
#   'Credit_History': 0,
#   'Dependents': '1',
#   'Education': 'Graduate',
#   'Gender': 'Female',
#   'Income': 'high',
#   'Married': 'Yes',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'Yes'},
#  {'Application_ID': 'LP001194',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '2',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001195',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001197',
#   'Application_Status': 'N',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Rural',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001198',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '1',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'medium',
#   'Married': 'Yes',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001199',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '2',
#   'Education': 'Not Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001205',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001206',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '3+',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001207',
#   'Application_Status': 'N',
#   'Credit_History': 0,
#   'Dependents': '0',
#   'Education': 'Not Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Rural',
#   'Self_Employed': 'Yes'},
#  {'Application_ID': 'LP001213',
#   'Application_Status': 'N',
#   'Credit_History': 0,
#   'Dependents': '1',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'medium',
#   'Married': 'Yes',
#   'Property_Area': 'Rural',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001222',
#   'Application_Status': 'N',
#   'Credit_History': 0,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Female',
#   'Income': 'medium',
#   'Married': 'No',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001225',
#   'Application_Status': 'N',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'medium',
#   'Married': 'Yes',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001228',
#   'Application_Status': 'N',
#   'Credit_History': 0,
#   'Dependents': '0',
#   'Education': 'Not Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'No',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001233',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '1',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'high',
#   'Married': 'Yes',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001238',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '3+',
#   'Education': 'Not Graduate',
#   'Gender': 'Male',
#   'Income': 'medium',
#   'Married': 'Yes',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'Yes'},
#  {'Application_ID': 'LP001241',
#   'Application_Status': 'N',
#   'Credit_History': 0,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Female',
#   'Income': 'medium',
#   'Married': 'No',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001243',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001245',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '2',
#   'Education': 'Not Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'Yes'},
#  {'Application_ID': 'LP001248',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'No',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001250',
#   'Application_Status': 'N',
#   'Credit_History': 0,
#   'Dependents': '3+',
#   'Education': 'Not Graduate',
#   'Gender': 'Male',
#   'Income': 'medium',
#   'Married': 'Yes',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001253',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '3+',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'medium',
#   'Married': 'Yes',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'Yes'},
#  {'Application_ID': 'LP001255',
#   'Application_Status': 'N',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'No',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001256',
#   'Application_Status': 'N',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'No',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001259',
#   'Application_Status': 'N',
#   'Credit_History': 1,
#   'Dependents': '1',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'Yes'},
#  {'Application_ID': 'LP001263',
#   'Application_Status': 'N',
#   'Credit_History': 0,
#   'Dependents': '3+',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001265',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Female',
#   'Income': 'low',
#   'Married': 'No',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001266',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '1',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'Yes'},
#  {'Application_ID': 'LP001267',
#   'Application_Status': 'N',
#   'Credit_History': 1,
#   'Dependents': '2',
#   'Education': 'Graduate',
#   'Gender': 'Female',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001275',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '1',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001279',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'No',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001282',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001289',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'medium',
#   'Married': 'No',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001310',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'medium',
#   'Married': 'Yes',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001316',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001318',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '2',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'medium',
#   'Married': 'Yes',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001319',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '2',
#   'Education': 'Not Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001322',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'medium',
#   'Married': 'No',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001325',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Not Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'No',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001327',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Female',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001333',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001334',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Not Graduate',
#   'Gender': 'Male',
#   'Income': 'medium',
#   'Married': 'Yes',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001343',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001345',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '2',
#   'Education': 'Not Graduate',
#   'Gender': 'Male',
#   'Income': 'medium',
#   'Married': 'Yes',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001349',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'medium',
#   'Married': 'No',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001356',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'medium',
#   'Married': 'Yes',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001367',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '1',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001369',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '2',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'high',
#   'Married': 'Yes',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001379',
#   'Application_Status': 'N',
#   'Credit_History': 0,
#   'Dependents': '2',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001384',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '3+',
#   'Education': 'Not Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001385',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'medium',
#   'Married': 'No',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001391',
#   'Application_Status': 'N',
#   'Credit_History': 0,
#   'Dependents': '0',
#   'Education': 'Not Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Rural',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001392',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '1',
#   'Education': 'Graduate',
#   'Gender': 'Female',
#   'Income': 'medium',
#   'Married': 'No',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'Yes'},
#  {'Application_ID': 'LP001401',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '1',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'high',
#   'Married': 'Yes',
#   'Property_Area': 'Rural',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001404',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Female',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001421',
#   'Application_Status': 'N',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'medium',
#   'Married': 'Yes',
#   'Property_Area': 'Rural',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001422',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Female',
#   'Income': 'high',
#   'Married': 'No',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001430',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Female',
#   'Income': 'medium',
#   'Married': 'No',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001431',
#   'Application_Status': 'Y',
#   'Credit_History': 0,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Female',
#   'Income': 'low',
#   'Married': 'No',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001432',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '2',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001439',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Not Graduate',
#   'Gender': 'Male',
#   'Income': 'medium',
#   'Married': 'Yes',
#   'Property_Area': 'Rural',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001449',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'No',
#   'Property_Area': 'Rural',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001451',
#   'Application_Status': 'N',
#   'Credit_History': 0,
#   'Dependents': '1',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'high',
#   'Married': 'Yes',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'Yes'},
#  {'Application_ID': 'LP001473',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'No',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001478',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'No',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001482',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'Yes'},
#  {'Application_ID': 'LP001487',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'medium',
#   'Married': 'No',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001488',
#   'Application_Status': 'N',
#   'Credit_History': 1,
#   'Dependents': '3+',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'medium',
#   'Married': 'Yes',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001489',
#   'Application_Status': 'N',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Female',
#   'Income': 'medium',
#   'Married': 'Yes',
#   'Property_Area': 'Rural',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001491',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '2',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'Yes'},
#  {'Application_ID': 'LP001492',
#   'Application_Status': 'N',
#   'Credit_History': 0,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'high',
#   'Married': 'No',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001493',
#   'Application_Status': 'N',
#   'Credit_History': 1,
#   'Dependents': '2',
#   'Education': 'Not Graduate',
#   'Gender': 'Male',
#   'Income': 'medium',
#   'Married': 'Yes',
#   'Property_Area': 'Rural',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001497',
#   'Application_Status': 'N',
#   'Credit_History': 1,
#   'Dependents': '2',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'medium',
#   'Married': 'Yes',
#   'Property_Area': 'Rural',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001498',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'medium',
#   'Married': 'No',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001504',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'medium',
#   'Married': 'No',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'Yes'},
#  {'Application_ID': 'LP001507',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001508',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '2',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'high',
#   'Married': 'Yes',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001514',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Female',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001516',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '2',
#   'Education': 'Graduate',
#   'Gender': 'Female',
#   'Income': 'high',
#   'Married': 'Yes',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001518',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '1',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001519',
#   'Application_Status': 'N',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Female',
#   'Income': 'high',
#   'Married': 'No',
#   'Property_Area': 'Rural',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001520',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'medium',
#   'Married': 'Yes',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001528',
#   'Application_Status': 'N',
#   'Credit_History': 0,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'medium',
#   'Married': 'No',
#   'Property_Area': 'Rural',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001529',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Rural',
#   'Self_Employed': 'Yes'},
#  {'Application_ID': 'LP001531',
#   'Application_Status': 'N',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'medium',
#   'Married': 'No',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001532',
#   'Application_Status': 'N',
#   'Credit_History': 1,
#   'Dependents': '2',
#   'Education': 'Not Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Rural',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001535',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'No',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001536',
#   'Application_Status': 'Y',
#   'Credit_History': 0,
#   'Dependents': '3+',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'high',
#   'Married': 'Yes',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001543',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '1',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'medium',
#   'Married': 'Yes',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001552',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'medium',
#   'Married': 'Yes',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001560',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Not Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001562',
#   'Application_Status': 'N',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'medium',
#   'Married': 'Yes',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001565',
#   'Application_Status': 'N',
#   'Credit_History': 0,
#   'Dependents': '1',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001570',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '2',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'medium',
#   'Married': 'Yes',
#   'Property_Area': 'Rural',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001572',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'medium',
#   'Married': 'Yes',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001574',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Rural',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001577',
#   'Application_Status': 'N',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Female',
#   'Income': 'medium',
#   'Married': 'Yes',
#   'Property_Area': 'Rural',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001578',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Rural',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001579',
#   'Application_Status': 'N',
#   'Credit_History': 0,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'No',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001580',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '2',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'medium',
#   'Married': 'Yes',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001586',
#   'Application_Status': 'N',
#   'Credit_History': 1,
#   'Dependents': '3+',
#   'Education': 'Not Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Rural',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001594',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'medium',
#   'Married': 'Yes',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001603',
#   'Application_Status': 'N',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Not Graduate',
#   'Gender': 'Male',
#   'Income': 'medium',
#   'Married': 'Yes',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'Yes'},
#  {'Application_ID': 'LP001606',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Rural',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001608',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '2',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Rural',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001610',
#   'Application_Status': 'N',
#   'Credit_History': 0,
#   'Dependents': '3+',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'medium',
#   'Married': 'Yes',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001616',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '1',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001630',
#   'Application_Status': 'N',
#   'Credit_History': 0,
#   'Dependents': '0',
#   'Education': 'Not Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'No',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001633',
#   'Application_Status': 'N',
#   'Credit_History': 0,
#   'Dependents': '1',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'medium',
#   'Married': 'Yes',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001636',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'medium',
#   'Married': 'Yes',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001637',
#   'Application_Status': 'N',
#   'Credit_History': 1,
#   'Dependents': '1',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'high',
#   'Married': 'Yes',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001639',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Female',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001640',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'high',
#   'Married': 'Yes',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'Yes'},
#  {'Application_ID': 'LP001641',
#   'Application_Status': 'N',
#   'Credit_History': 0,
#   'Dependents': '1',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Rural',
#   'Self_Employed': 'Yes'},
#  {'Application_ID': 'LP001647',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'medium',
#   'Married': 'Yes',
#   'Property_Area': 'Rural',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001653',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Not Graduate',
#   'Gender': 'Male',
#   'Income': 'medium',
#   'Married': 'No',
#   'Property_Area': 'Rural',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001656',
#   'Application_Status': 'N',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'high',
#   'Married': 'No',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001657',
#   'Application_Status': 'N',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Not Graduate',
#   'Gender': 'Male',
#   'Income': 'medium',
#   'Married': 'Yes',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001658',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'No',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001664',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'medium',
#   'Married': 'No',
#   'Property_Area': 'Rural',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001665',
#   'Application_Status': 'N',
#   'Credit_History': 1,
#   'Dependents': '1',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001666',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'medium',
#   'Married': 'No',
#   'Property_Area': 'Rural',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001669',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Not Graduate',
#   'Gender': 'Female',
#   'Income': 'low',
#   'Married': 'No',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001673',
#   'Application_Status': 'N',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'high',
#   'Married': 'No',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'Yes'},
#  {'Application_ID': 'LP001674',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '1',
#   'Education': 'Not Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001677',
#   'Application_Status': 'Y',
#   'Credit_History': 0,
#   'Dependents': '2',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'medium',
#   'Married': 'No',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001682',
#   'Application_Status': 'N',
#   'Credit_History': 1,
#   'Dependents': '3+',
#   'Education': 'Not Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001688',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '1',
#   'Education': 'Not Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001691',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '2',
#   'Education': 'Not Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001692',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Not Graduate',
#   'Gender': 'Female',
#   'Income': 'medium',
#   'Married': 'No',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001693',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Female',
#   'Income': 'low',
#   'Married': 'No',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001698',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Not Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'No',
#   'Property_Area': 'Rural',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001699',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'No',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001702',
#   'Application_Status': 'N',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'No',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001708',
#   'Application_Status': 'N',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Female',
#   'Income': 'high',
#   'Married': 'No',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001711',
#   'Application_Status': 'N',
#   'Credit_History': 0,
#   'Dependents': '3+',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001713',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '1',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'medium',
#   'Married': 'Yes',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'Yes'},
#  {'Application_ID': 'LP001715',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '3+',
#   'Education': 'Not Graduate',
#   'Gender': 'Male',
#   'Income': 'medium',
#   'Married': 'Yes',
#   'Property_Area': 'Rural',
#   'Self_Employed': 'Yes'},
#  {'Application_ID': 'LP001716',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001720',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '3+',
#   'Education': 'Not Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001722',
#   'Application_Status': 'N',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Rural',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001726',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001736',
#   'Application_Status': 'N',
#   'Credit_History': 0,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001743',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '2',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'medium',
#   'Married': 'Yes',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001744',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'No',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001749',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'medium',
#   'Married': 'Yes',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001750',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'medium',
#   'Married': 'Yes',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP001751',
#   'Application_Status': 'N',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
# ...
#   'Married': 'Yes',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP002738',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '2',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'No',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP002739',
#   'Application_Status': 'N',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Not Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Rural',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP002740',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '3+',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'medium',
#   'Married': 'Yes',
#   'Property_Area': 'Rural',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP002741',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '1',
#   'Education': 'Graduate',
#   'Gender': 'Female',
#   'Income': 'medium',
#   'Married': 'Yes',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP002743',
#   'Application_Status': 'N',
#   'Credit_History': 0,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Female',
#   'Income': 'low',
#   'Married': 'No',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP002755',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '1',
#   'Education': 'Not Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP002767',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Rural',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP002768',
#   'Application_Status': 'N',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Not Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'No',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP002772',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'No',
#   'Property_Area': 'Rural',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP002776',
#   'Application_Status': 'N',
#   'Credit_History': 0,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Female',
#   'Income': 'medium',
#   'Married': 'No',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP002777',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Rural',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP002778',
#   'Application_Status': 'N',
#   'Credit_History': 0,
#   'Dependents': '2',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'medium',
#   'Married': 'Yes',
#   'Property_Area': 'Rural',
#   'Self_Employed': 'Yes'},
#  {'Application_ID': 'LP002784',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '1',
#   'Education': 'Not Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Rural',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP002785',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '1',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP002788',
#   'Application_Status': 'N',
#   'Credit_History': 0,
#   'Dependents': '0',
#   'Education': 'Not Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP002789',
#   'Application_Status': 'N',
#   'Credit_History': 0,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Rural',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP002792',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '1',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'medium',
#   'Married': 'Yes',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP002795',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '3+',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'high',
#   'Married': 'Yes',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'Yes'},
#  {'Application_ID': 'LP002798',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP002804',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Female',
#   'Income': 'medium',
#   'Married': 'Yes',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP002807',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '2',
#   'Education': 'Not Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP002813',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '1',
#   'Education': 'Graduate',
#   'Gender': 'Female',
#   'Income': 'high',
#   'Married': 'Yes',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'Yes'},
#  {'Application_ID': 'LP002820',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'medium',
#   'Married': 'Yes',
#   'Property_Area': 'Rural',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP002821',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Not Graduate',
#   'Gender': 'Male',
#   'Income': 'medium',
#   'Married': 'No',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'Yes'},
#  {'Application_ID': 'LP002832',
#   'Application_Status': 'N',
#   'Credit_History': 0,
#   'Dependents': '2',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'medium',
#   'Married': 'Yes',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP002836',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'No',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP002837',
#   'Application_Status': 'N',
#   'Credit_History': 0,
#   'Dependents': '3+',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Rural',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP002840',
#   'Application_Status': 'N',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Female',
#   'Income': 'low',
#   'Married': 'No',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP002841',
#   'Application_Status': 'N',
#   'Credit_History': 0,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP002842',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '1',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP002855',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '2',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'high',
#   'Married': 'Yes',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP002862',
#   'Application_Status': 'N',
#   'Credit_History': 1,
#   'Dependents': '2',
#   'Education': 'Not Graduate',
#   'Gender': 'Male',
#   'Income': 'medium',
#   'Married': 'Yes',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP002863',
#   'Application_Status': 'N',
#   'Credit_History': 1,
#   'Dependents': '3+',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'medium',
#   'Married': 'Yes',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP002868',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '2',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP002874',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'No',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP002877',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '1',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Rural',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP002892',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '2',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'medium',
#   'Married': 'Yes',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP002893',
#   'Application_Status': 'N',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'No',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP002894',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Female',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP002911',
#   'Application_Status': 'N',
#   'Credit_History': 0,
#   'Dependents': '1',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Rural',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP002912',
#   'Application_Status': 'N',
#   'Credit_History': 1,
#   'Dependents': '1',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'medium',
#   'Married': 'Yes',
#   'Property_Area': 'Rural',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP002916',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP002917',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Not Graduate',
#   'Gender': 'Female',
#   'Income': 'low',
#   'Married': 'No',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP002926',
#   'Application_Status': 'N',
#   'Credit_History': 0,
#   'Dependents': '2',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'Yes'},
#  {'Application_ID': 'LP002928',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP002931',
#   'Application_Status': 'N',
#   'Credit_History': 1,
#   'Dependents': '2',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'medium',
#   'Married': 'Yes',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'Yes'},
#  {'Application_ID': 'LP002936',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Rural',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP002938',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'high',
#   'Married': 'Yes',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'Yes'},
#  {'Application_ID': 'LP002940',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Not Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'No',
#   'Property_Area': 'Rural',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP002941',
#   'Application_Status': 'N',
#   'Credit_History': 1,
#   'Dependents': '2',
#   'Education': 'Not Graduate',
#   'Gender': 'Male',
#   'Income': 'medium',
#   'Married': 'Yes',
#   'Property_Area': 'Rural',
#   'Self_Employed': 'Yes'},
#  {'Application_ID': 'LP002945',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'medium',
#   'Married': 'Yes',
#   'Property_Area': 'Rural',
#   'Self_Employed': 'Yes'},
#  {'Application_ID': 'LP002948',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '2',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'medium',
#   'Married': 'Yes',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP002953',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '3+',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'medium',
#   'Married': 'Yes',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP002958',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'No',
#   'Property_Area': 'Rural',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP002959',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '1',
#   'Education': 'Graduate',
#   'Gender': 'Female',
#   'Income': 'high',
#   'Married': 'Yes',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP002960',
#   'Application_Status': 'N',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Not Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP002961',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '1',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP002964',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '2',
#   'Education': 'Not Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Rural',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP002974',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'low',
#   'Married': 'Yes',
#   'Property_Area': 'Rural',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP002978',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Female',
#   'Income': 'low',
#   'Married': 'No',
#   'Property_Area': 'Rural',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP002979',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '3+',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'medium',
#   'Married': 'Yes',
#   'Property_Area': 'Rural',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP002983',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '1',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'medium',
#   'Married': 'Yes',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP002984',
#   'Application_Status': 'Y',
#   'Credit_History': 1,
#   'Dependents': '2',
#   'Education': 'Graduate',
#   'Gender': 'Male',
#   'Income': 'medium',
#   'Married': 'Yes',
#   'Property_Area': 'Urban',
#   'Self_Employed': 'No'},
#  {'Application_ID': 'LP002990',
#   'Application_Status': 'N',
#   'Credit_History': 0,
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Gender': 'Female',
#   'Income': 'medium',
#   'Married': 'No',
#   'Property_Area': 'Semiurban',
#   'Self_Employed': 'Yes'}]

# %% [markdown]
# 4.3 - Once Python reads data from the API, utilize PySpark to load data into RDBMS (SQL). The table name should be cdw_sapp_loan_application in the database.
#
# Note: Use the “creditcard_capstone” database.

# %%
from pyspark.sql.types import *
from pyspark.sql.functions import *
from pyspark.sql import SparkSession
ss = SparkSession.builder.appName("Credit_Card_System").getOrCreate()
ss
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://Lazzypotatoe.mshome.net:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.4.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Credit_Card_System</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
# ss.read.json() only accepts a file or path as its input, hence can't use it to read json data here
df = ss.createDataFrame(data)
df.printSchema()
df.show(10, truncate=False)
# Out:
# root
#  |-- Application_ID: string (nullable = true)
#  |-- Application_Status: string (nullable = true)
#  |-- Credit_History: long (nullable = true)
#  |-- Dependents: string (nullable = true)
#  |-- Education: string (nullable = true)
#  |-- Gender: string (nullable = true)
#  |-- Income: string (nullable = true)
#  |-- Married: string (nullable = true)
#  |-- Property_Area: string (nullable = true)
#  |-- Self_Employed: string (nullable = true)
#
# +--------------+------------------+--------------+----------+------------+------+------+-------+-------------+-------------+
# |Application_ID|Application_Status|Credit_History|Dependents|Education   |Gender|Income|Married|Property_Area|Self_Employed|
# +--------------+------------------+--------------+----------+------------+------+------+-------+-------------+-------------+
# |LP001002      |Y                 |1             |0         |Graduate    |Male  |medium|No     |Urban        |No           |
# |LP001003      |N                 |1             |1         |Graduate    |Male  |medium|Yes    |Rural        |No           |
# |LP001005      |Y                 |1             |0         |Graduate    |Male  |low   |Yes    |Urban        |Yes          |
# |LP001006      |Y                 |1             |0         |Not Graduate|Male  |low   |Yes    |Urban        |No           |
# |LP001008      |Y                 |1             |0         |Graduate    |Male  |medium|No     |Urban        |No           |
# |LP001011      |Y                 |1             |2         |Graduate    |Male  |medium|Yes    |Urban        |Yes          |
# |LP001013      |Y                 |1             |0         |Not Graduate|Male  |low   |Yes    |Urban        |No           |
# |LP001014      |N                 |0             |3+        |Graduate    |Male  |low   |Yes    |Semiurban    |No           |
# |LP001018      |Y                 |1             |2         |Graduate    |Male  |medium|Yes    |Urban        |No           |
# |LP001020      |N                 |1             |1         |Graduate    |Male  |high  |Yes    |Semiurban    |No           |
# +--------------+------------------+--------------+----------+------------+------+------+-------+-------------+-------------+
# only showing top 10 rows

# %%
# convert income column to title case
df = df.withColumn('Income', initcap(col('Income')))
df.show(10, truncate=False)
# Out:
# +--------------+------------------+--------------+----------+------------+------+------+-------+-------------+-------------+
# |Application_ID|Application_Status|Credit_History|Dependents|Education   |Gender|Income|Married|Property_Area|Self_Employed|
# +--------------+------------------+--------------+----------+------------+------+------+-------+-------------+-------------+
# |LP001002      |Y                 |1             |0         |Graduate    |Male  |Medium|No     |Urban        |No           |
# |LP001003      |N                 |1             |1         |Graduate    |Male  |Medium|Yes    |Rural        |No           |
# |LP001005      |Y                 |1             |0         |Graduate    |Male  |Low   |Yes    |Urban        |Yes          |
# |LP001006      |Y                 |1             |0         |Not Graduate|Male  |Low   |Yes    |Urban        |No           |
# |LP001008      |Y                 |1             |0         |Graduate    |Male  |Medium|No     |Urban        |No           |
# |LP001011      |Y                 |1             |2         |Graduate    |Male  |Medium|Yes    |Urban        |Yes          |
# |LP001013      |Y                 |1             |0         |Not Graduate|Male  |Low   |Yes    |Urban        |No           |
# |LP001014      |N                 |0             |3+        |Graduate    |Male  |Low   |Yes    |Semiurban    |No           |
# |LP001018      |Y                 |1             |2         |Graduate    |Male  |Medium|Yes    |Urban        |No           |
# |LP001020      |N                 |1             |1         |Graduate    |Male  |High  |Yes    |Semiurban    |No           |
# +--------------+------------------+--------------+----------+------------+------+------+-------+-------------+-------------+
# only showing top 10 rows

# %%
# load data from df into new table in mysql db
df.write.format("jdbc")\
    .mode("append")\
    .options(user=os.environ.get("MYSQL_DB_USER"),
             password=os.environ.get("MYSQL_DB_PW"),
             url="jdbc:mysql://localhost:3306/creditcard_capstone",
             dbtable="creditcard_capstone.CDW_SAPP_LOAN_APPLICATION")\
    .save()

# %%
#  MySQL  localhost:33060+ ssl  creditcard_capstone  SQL > SHOW TABLES;
# +-------------------------------+
# | Tables_in_creditcard_capstone |
# +-------------------------------+
# | cdw_sapp_branch               |
# | cdw_sapp_credit_card          |
# | cdw_sapp_customer             |
# | cdw_sapp_loan_application     |  <---
# +-------------------------------+
# 4 rows in set (0.0020 sec)

# %% [markdown]
# ### 5. Functional Requirements - Data Analysis and Visualization for LOAN Application
# After the data is loaded into the database, the business analyst team wants to analyze and visualize the data.
#
# Use Python libraries for the below requirements:
#
# 5.1 - Find and plot the percentage of applications approved for self-employed applicants.
#
# Note: Save a copy of the visualization to a folder in your github, making sure it is PROPERLY NAMED!

# %%
import mysql.connector
from tabulate import tabulate
import os
import matplotlib.pyplot as plt

# %%
cnx = mysql.connector.connect(host='localhost',
                              user=os.environ.get('MYSQL_DB_USER'),
                              password=os.environ.get('MYSQL_DB_PW'))
cursor = cnx.cursor()
cursor.execute("use creditcard_capstone")

# %%
q1_ct = '''select self_employed, round(sum(case when application_status='Y' then 1 else 0 end), 2) as approved,
     round(sum(case when application_status='N' then 1 else 0 end), 2) as rejected
     from cdw_sapp_loan_application 
     group by self_employed'''
cursor.execute(q1_ct)
ct = cursor.fetchall()
headers = cursor.column_names
table_ct = tabulate(ct, headers=headers, tablefmt="pretty", stralign="left")
print(table_ct)

type = ['Others', 'Self_Employed']
approved = [row[1] for row in ct]
rejected = [row[2] for row in ct]
plt.style.use('ggplot')
plt.figure(5.1, figsize=(6,5), layout='tight')
plt.bar(type, approved, label='Approved', width=0.4, color='green', alpha=0.7)
plt.bar(type, rejected, label='Rejected', width=0.4, color='red', alpha=0.7, bottom=approved)
plt.title("Loan Application Study by\nEmployment Category 2018", fontsize=16, fontweight='bold', pad=20)
plt.xlim(-1, len(type))
plt.ylabel("Number of Application Processed", fontsize=10)
plt.ylim(0, max(approved)+max(rejected)+40)
plt.legend()
caption = "Figure 5.1. Loan approval rate is about the same for both employment \ntypes and is moderately positive(>65%). Compared to others, self-employed \nindividuals make up only a small portion of the total number of applicants. "
plt.figtext(0.13, -0.025, caption, ha='left', va='center', fontsize=9.5)

q1_per = '''select self_employed, round(sum(case when application_status='Y' then 1 else 0 end)/count(*)*100, 2) as 'approved %',
     round(sum(case when application_status='N' then 1 else 0 end)/count(*)*100, 2) as 'rejected %'
     from cdw_sapp_loan_application 
     group by self_employed'''
cursor.execute(q1_per)
per = cursor.fetchall()
headers = cursor.column_names
table_per = tabulate(per, headers=headers, tablefmt="pretty", stralign="left")
print(table_per)
type = ['Others', 'Self_Employed']
approved_per = [row[1] for row in per]
rejected_per = [row[2] for row in per]
# add approval and rejction rate as labels onto the bars
for i, (app_ct, rej_ct, app_per, rej_per) in enumerate(zip(approved, rejected, approved_per, rejected_per)):
    plt.text(i, app_ct/2, f'{app_per}%', ha='center', va='center', fontsize=9)
    plt.text(i, app_ct + rej_ct/2, f'{rej_per}%',
             ha='center', va='center', fontsize=9)
plt.show()
# Out:
# +---------------+----------+----------+
# | self_employed | approved | rejected |
# +---------------+----------+----------+
# | No            | 301      | 140      |
# | Yes           | 46       | 24       |
# +---------------+----------+----------+
# +---------------+------------+------------+
# | self_employed | approved % | rejected % |
# +---------------+------------+------------+
# | No            | 68.25      | 31.75      |
# | Yes           | 65.71      | 34.29      |
# +---------------+------------+------------+

# %%
# below code is replaced with above code
q1 = '''select self_employed, application_status, count(application_status) as application_count 
    from cdw_sapp_loan_application 
    where self_employed ='Yes' 
    group by application_status'''
cursor.execute(q1)
data1 = cursor.fetchall()
headers = cursor.column_names
table = tabulate(data1, headers=headers, tablefmt="pretty", stralign="left")
print(table)
status = [row[1] for row in data1]
count = [row[2] for row in data1]
plt.style.use('ggplot')
plt.figure(4, figsize=(6, 5), layout='tight')
plt.pie(count, labels=['Approved', 'Rejected'], autopct='%1.1f%%', shadow=True)
plt.title("Application Status for Self-Employed Applicants",
          fontsize=16, fontweight='bold', pad=25)
plt.axis('equal')
plt.show()
# Out:
# +---------------+--------------------+-------------------+
# | self_employed | application_status | Application_Count |
# +---------------+--------------------+-------------------+
# | Yes           | Y                  | 46                |
# | Yes           | N                  | 24                |
# +---------------+--------------------+-------------------+

# %% [markdown]
# 5.2 - Find the percentage of rejection for married male applicants.
#
# Note: Save a copy of the visualization to a folder in your github, making sure it is PROPERLY NAMED!

# %%
q2 = '''select gender, married, application_status, count(application_status) as Application_Count 
    from cdw_sapp_loan_application 
    where gender = 'Male' and married = 'Yes' 
    group by application_status'''
cursor.execute(q2)
data2 = cursor.fetchall()
headers = cursor.column_names
table = tabulate(data2, headers=headers, tablefmt="pretty", stralign="left")
print(table)

status = [row[2] for row in data2]
count = [row[3] for row in data2]

plt.style.use('ggplot')
plt.figure(4, figsize=(6, 5), layout='tight')
plt.pie(count, labels=['Approved', 'Rejected'], autopct='%1.1f%%', shadow=True)
plt.title("Application Status for Married Male Applicants",
          fontsize=16, fontweight='bold', pad=25)
plt.axis('equal')
plt.show()
# Out:
# +--------+---------+--------------------+-------------------+
# | gender | married | application_status | Application_Count |
# +--------+---------+--------------------+-------------------+
# | Male   | Yes     | N                  | 87                |
# | Male   | Yes     | Y                  | 219               |
# +--------+---------+--------------------+-------------------+

# %%
q2_ct = '''select concat(married, (","), gender) as married_gender, round(sum(case when application_status='Y' then 1 else 0 end), 2) as approved,
     round(sum(case when application_status='N' then 1 else 0 end), 2) as rejected
     from cdw_sapp_loan_application 
     group by married_gender
     order by married_gender'''
cursor.execute(q2_ct)
ct = cursor.fetchall()
headers = cursor.column_names
table_ct = tabulate(ct, headers=headers, tablefmt="pretty", stralign="left")
print(table_ct)
# create a horizontal bar graph
type = ['Single Female', 'Single Male', 'Married Female', 'Married Male']
approved = [row[1] for row in ct]
rejected = [row[2] for row in ct]
plt.style.use('ggplot')
plt.figure(5.2, figsize=(9, 6))
plt.barh(type, approved, label='Approved',
         height=0.5, color='green', alpha=0.7)
plt.barh(type, rejected, label='Rejected', height=0.5,
         color='red', alpha=0.7, left=approved)
# customize the plot
plt.xlabel('Number of Application Processed')
plt.xlim(-0, max(approved)+max(rejected)+40)
plt.ylim(-1, len(type))
plt.title("Loan Application Study by\nGender & Marital Status 2018",
          fontsize=16, fontweight='bold', pad=20)
plt.legend(loc='lower right')
caption = "Figure 5.2. Loan application number is dramatically high for married males and low for married females, \nwhich possibly suggests that most married males are the breadwinners in the family. The other groups \nalso seem more less likely to apply for loans compared to married males, which makes married males \nthe target customers. But again, loan approval rate is quite positive(>62%) for all."
plt.figtext(0.13, -0.04, caption, ha='left', va='center', fontsize=9.5)

q2_percentage = '''select concat(married, (","), gender) as married_gender, round(sum(case when application_status='Y' then 1 else 0 end)/count(*)*100, 2) as 'approved %',
     round(sum(case when application_status='N' then 1 else 0 end)/count(*)*100, 2) as 'rejected %'
     from cdw_sapp_loan_application 
     group by married_gender
     order by married_gender'''
cursor.execute(q2_percentage)
percentage = cursor.fetchall()
headers = cursor.column_names
table_percentage = tabulate(
    percentage, headers=headers, tablefmt="pretty", stralign="left")
print(table_percentage)
approved_percentage = [row[1] for row in percentage]
rejected_percentage = [row[2] for row in percentage]
# add data values to the bars
for i, (app_ct, rej_ct, app_per, rej_per) in enumerate(zip(approved, rejected, approved_percentage, rejected_percentage)):
    # conditionally add percentage labels if the bar width is greater than the minimum width
    if app_ct < 40 and rej_ct < 40:
        intersection = app_ct + rej_ct
        plt.text(intersection, i, f'{app_per}% / {rej_per}%',
                 ha='left', va='center', color='black')
    else:
        plt.text(app_ct/2, i, f'{app_per}%',
                 ha='center', va='center', fontsize=9)
        plt.text(app_ct + rej_ct/2, i,
                 f'{rej_per}%', ha='center', va='center', fontsize=9)
# show the plot
plt.show()
# Out:
# +----------------+----------+----------+
# | married_gender | approved | rejected |
# +----------------+----------+----------+
# | No,Female      | 40       | 26       |
# | No,Male        | 71       | 43       |
# | Yes,Female     | 17       | 8        |
# | Yes,Male       | 219      | 87       |
# +----------------+----------+----------+
# +----------------+------------+------------+
# | married_gender | approved % | rejected % |
# +----------------+------------+------------+
# | No,Female      | 60.61      | 39.39      |
# | No,Male        | 62.28      | 37.72      |
# | Yes,Female     | 68.00      | 32.00      |
# | Yes,Male       | 71.57      | 28.43      |
# +----------------+------------+------------+

# %%
# # wrong query
# q2 = '''select concat(married, (","), self_employed) as married_self_employed, round(sum(case when application_status='Y' then 1 else 0 end)/count(*)*100, 2) as approved,
#      round(sum(case when application_status='N' then 1 else 0 end)/count(*)*100, 2) as rejected
#      from cdw_sapp_loan_application
#      group by married_self_employed'''
# cursor.execute(q2)
# data2 = cursor.fetchall()
# headers = cursor.column_names
# table = tabulate(data2, headers = headers, tablefmt = "pretty", stralign = "left")
# print(table)
# type = ['Others & Single', 'Others & Married', 'Self-Employed & Married', 'Self-Employed & Single']
# approved = [row[1] for row in data2]
# rejected = [row[2] for row in data2]
# # create a horizontal bar graph
# plt.style.use('ggplot')
# plt.figure(4, figsize=(7,4.5))
# plt.barh(type, approved, label='Approved', height=0.5, color='green', alpha=0.7)
# plt.barh(type, rejected, label='Rejected', height=0.5, color='red', alpha=0.7, left=approved)
# # customize the plot
# plt.xlabel('Percentage')
# plt.xlim(-0, 140)
# plt.ylim(-1, len(type))
# plt.title("Loan Application Study by \nEmployment Category & Marital Status", fontsize=16, fontweight='bold', pad=20)
# plt.legend(loc='upper right')
# # add data values to the bars
# for i, (app_val, rej_val) in enumerate(zip(approved, rejected)):
#     plt.text(app_val / 2, i, f'{app_val:.2f}%', ha='center', va='center', color='white')
#     plt.text(app_val + rej_val / 2, i, f'{rej_val:.2f}%', ha='center', va='center', color='white')
# # show the plot
# plt.show()
# Out:
# +-----------------------+----------+----------+
# | married_self_employed | approved | rejected |
# +-----------------------+----------+----------+
# | No,No                 | 62.42    | 37.58    |
# | Yes,No                | 71.48    | 28.52    |
# | Yes,Yes               | 70.21    | 29.79    |
# | No,Yes                | 56.52    | 43.48    |
# +-----------------------+----------+----------+

# %% [markdown]
# 5.3 - Find and plot the top three months with the largest volume of transaction data.
#
# Note: Save a copy of the visualization to a folder in your github, making sure it is PROPERLY NAMED!

# %%
q3 = '''select date_format(timeid, '%b') as MONTH, count(distinct transaction_id) as TRXN_VOLUME 
    from cdw_sapp_credit_card 
    group by MONTH 
    order by TRXN_VOLUME desc'''
cursor.execute(q3)
data3 = cursor.fetchall()
headers = cursor.column_names
table = tabulate(data3, headers=headers, tablefmt="pretty", stralign="left")
print(table)
month = [row[0] for row in data3]  # x-axis
trxn_vol = [row[1] for row in data3]  # y-axis
plt.style.use('ggplot')
plt.figure(5.3, figsize=(10, 6))
plt.bar(month, trxn_vol, width=0.6)
plt.title("Annual Transaction Volume of Banks 2018",
          fontsize=16, fontweight='bold', pad=18)
plt.ylabel("Transaction Volume", fontsize=10)
plt.ylim(0, 5000)
caption = "Figure 5.3. Annual transaction volume is very stable year round, no obvious growth in particular month."
plt.figtext(0.14, 0, caption, ha='left', va='center', fontsize=10)
# add spending amounts as labels on top of the bars
for x, y in zip(month, trxn_vol):
    plt.text(x, y, str(y), ha="center", va="bottom", fontsize=9)
plt.show()
# Out:
# +-------+-------------+
# | MONTH | TRXN_VOLUME |
# +-------+-------------+
# | Feb   | 3959        |
# | May   | 3946        |
# | Oct   | 3946        |
# | Dec   | 3936        |
# | Jul   | 3935        |
# | Nov   | 3901        |
# | Sep   | 3886        |
# | Aug   | 3861        |
# | Mar   | 3851        |
# | Apr   | 3840        |
# | Jun   | 3819        |
# | Jan   | 3814        |
# +-------+-------------+

# %% [markdown]
# 5.4 - Find and plot which branch processed the highest total dollar value of healthcare transactions.
#
# Note: Save a copy of the visualization to a folder in your github, making sure it is PROPERLY NAMED!.

# %%
q4 = '''select cc.branch_code as BRANCH_CODE, concat(br.branch_name, ' ', br.branch_code, ' in ', br.branch_state) as BRANCH, round(sum(transaction_value),2) as TOTAL_TRXN_VAL
    from cdw_sapp_credit_card cc
    inner join cdw_sapp_branch br
    on cc.branch_code = br.branch_code
    where cc.transaction_type = 'Healthcare'
    group by cc.branch_code, BRANCH
    order by TOTAL_TRXN_VAL desc limit 10'''
cursor.execute(q4)
data4 = cursor.fetchall()
headers = cursor.column_names
table = tabulate(data4, headers=headers, tablefmt="pretty", stralign="left")
print(table)
branch = [row[1] for row in data4]  # y-axis
trxn_val = [row[2] for row in data4]  # x-axis
plt.style.use('ggplot')
plt.figure(7, figsize=(7, 5))
plt.barh(branch, trxn_val, height=0.45)
plt.title("Top 10 Banks with Highest Transaction \nSpending in Healthcare 2018",
          loc='center', fontsize=16, fontweight='bold', pad=18)
plt.xlabel("Transaction Value ($)", fontsize=10)
plt.xlim(0, 6000)
plt.yticks(range(len(branch)), fontsize=9.5)
plt.ylim(-1, len(branch))
# Invert the y-axis for ascending order from bottom to top
plt.gca().invert_yaxis()
# add customer count as labels on top of the bars
for index, value in enumerate(trxn_val):
    plt.text(value, index, f"$ {value}", va='center', fontsize=8)
plt.show()
# Out:
# +-------------+------------------------+----------------+
# | BRANCH_CODE | BRANCH                 | TOTAL_TRXN_VAL |
# +-------------+------------------------+----------------+
# | 25          | Example Bank 25 in MI  | 4370.18        |
# | 60          | Example Bank 60 in VA  | 4072.04        |
# | 83          | Example Bank 83 in WI  | 4003.37        |
# | 36          | Example Bank 36 in AR  | 3823.87        |
# | 111         | Example Bank 111 in NC | 3720.27        |
# | 90          | Example Bank 90 in OH  | 3697.16        |
# | 21          | Example Bank 21 in WA  | 3651.74        |
# | 109         | Example Bank 109 in IA | 3603.67        |
# | 42          | Example Bank 42 in OH  | 3603.25        |
# | 70          | Example Bank 70 in MA  | 3594.35        |
# +-------------+------------------------+----------------+

# %%
# refactord code from code above
def reuse(q):
    try:
        with connect_to_mysql() as cnx:
            cursor = cnx.cursor()
            cursor.execute("use creditcard_capstone")
            query = q
            cursor.execute(query)
            data = cursor.fetchall()
            headers = cursor.column_names
            table = tabulate(data, headers=headers,
                             tablefmt="pretty", stralign="left")
            print(table)

    except Error as e:
        print(e)


def get_data():
    q = '''select cc.branch_code as BRANCH_CODE, concat(br.branch_name, ' ', br.branch_code, ' in ', br.branch_state) as BRANCH, round(sum(transaction_value),2) as TOTAL_TRXN_VAL
    from cdw_sapp_credit_card cc
    inner join cdw_sapp_branch br
    on cc.branch_code = br.branch_code
    where cc.transaction_type = 'Healthcare'
    group by cc.branch_code, BRANCH
    order by TOTAL_TRXN_VAL desc limit 10'''
    reuse(q)
    branch = [row[1] for row in data4]  # y-axis
    trxn_val = [row[2] for row in data4]  # x-axis
    plt.style.use('ggplot')
    plt.figure(5.4, figsize=(10, 6.5), layout='tight')
    plt.barh(branch, trxn_val, height=0.45)
    plt.title("Top 10 Banks with Highest Transaction \nSpending in Healthcare 2018",
              loc='center', fontsize=16, fontweight='bold', pad=18)
    plt.xlabel("Transaction Value ($)", fontsize=10)
    plt.xlim(0, 6000)
    plt.yticks(range(len(branch)), fontsize=9.5)
    plt.ylim(-1, len(branch))
    # Invert the y-axis for ascending order from bottom to top
    plt.gca().invert_yaxis()
    # add customer count as labels on top of the bars
    for index, value in enumerate(trxn_val):
        plt.text(value, index, f"$ {value}", va='center', fontsize=9)
    plt.show()


get_data()
# Out:
# +-------------+------------------------+----------------+
# | BRANCH_CODE | BRANCH                 | TOTAL_TRXN_VAL |
# +-------------+------------------------+----------------+
# | 25          | Example Bank 25 in MI  | 4370.18        |
# | 60          | Example Bank 60 in VA  | 4072.04        |
# | 83          | Example Bank 83 in WI  | 4003.37        |
# | 36          | Example Bank 36 in AR  | 3823.87        |
# | 111         | Example Bank 111 in NC | 3720.27        |
# | 90          | Example Bank 90 in OH  | 3697.16        |
# | 21          | Example Bank 21 in WA  | 3651.74        |
# | 109         | Example Bank 109 in IA | 3603.67        |
# | 42          | Example Bank 42 in OH  | 3603.25        |
# | 70          | Example Bank 70 in MA  | 3594.35        |
# +-------------+------------------------+----------------+

# %%
ss.stop()

# %%
# Check active session using SparkSession.getActiveSession()
if SparkSession.getActiveSession() is not None:
    print("An active Spark session is available.")
else:
    print("No active Spark session found.")
# Out:
# No active Spark session found.
